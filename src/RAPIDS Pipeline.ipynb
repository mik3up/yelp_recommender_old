# %% [markdown]
# # Restaurant Recommender EDA
#
# This notebook will take a dataset from Yelp and get it ready for a machine learning model using the GPU platform, RAPIDS
#
# * More information on RAPIDS and how to set up GPU computing on your machine here, https://rapids.ai/index.html

# %% [markdown]
# # Check if GPU is RAPIDS ready
#
# * If running this notebook on Google Colab, go to Runtime > 'Change Runtime Type' > Hardware Accelerator > select GPU
#
# * Then run the code below.
#
# * If the code errors out, your Colab instance does not a RAPIDS enables GPU, go to Runtime > 'Restart all runtimes' and try again

# %%
# !wget -nc https://github.com/rapidsai/notebooks-extended/raw/master/utils/rapids-colab.sh
# !bash rapids-colab.sh

import sys, os

sys.path.append('/usr/local/lib/python3.6/site-packages/')
os.environ['NUMBAPRO_NVVM'] = '/usr/local/cuda/nvvm/lib64/libnvvm.so'
os.environ['NUMBAPRO_LIBDEVICE'] = '/usr/local/cuda/nvvm/libdevice/'
# Out:
# File ‘rapids-colab.sh’ already there; not retrieving.
#
# File ‘env-check.py’ already there; not retrieving.
#
# Checking for GPU type:
# *********************************************
# Woo! Your instance has the right kind of GPU!
# *********************************************
#
#
# *********************************************
# Your Google Colab instance is RAPIDS ready!
# *********************************************

# %% [markdown]
# # Download the Yelp Dataset and Upload it to this instance

# %%
from google.colab import files
review_upload = files.upload()
# Out:
#      <input type="file" id="files-757e49f2-9ec5-4af3-ad1b-b54509983cbb" name="files[]" multiple disabled />
#      <output id="result-757e49f2-9ec5-4af3-ad1b-b54509983cbb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
type(uploaded)
# Out:
# dict

# %% [markdown]
# # Data Pipeline
#
# * <b>Objective:</b> parse the relevant features from each dataset into one df
# * <i>Dataset comes from https://www.yelp.com/dataset/challenge</i>

# %%
import time
import json
import os
import pandas as pd
pd.set_option('display.max_columns', None)

import collections
from collections import Counter
from collections import OrderedDict

# %%
import pickle
import sys

#pd.to_pickle fails for large files, this function takes care of that issue
def save_as_pickled_object(obj, filepath):
    """
    This is a defensive way to write pickle.write, allowing for very large files on all platforms
    """
    max_bytes = 2**31 - 1
    bytes_out = pickle.dumps(obj)
    n_bytes = sys.getsizeof(bytes_out)
    with open(filepath, 'wb') as f_out:
        for idx in range(0, n_bytes, max_bytes):
            f_out.write(bytes_out[idx:idx+max_bytes])

# %% [markdown]
# # Load Yelp Dataset into DF
#
# Download the Yelp dataset from https://www.yelp.com/dataset

# %% [markdown]
# ## Load Datasets

# %%
def load_dataset(file):
    '''
    reads in a json file as a list, then transformed into a pandas df, and outputs to a pickle file for easier access
    
    input: json filepath
    output: pandas dataframe
    '''
    #reads in the json file
    start = time.time()
    raw_data = []
    with open(file) as f:
        for line in f:
            raw_data.append(json.loads(line))
    end = time.time()
    print('loaded {} lines of data into a list in {} seconds'.format(len(raw_data), end-start))

    # stores data into a df
    start = time.time()
    order = list(raw_data[0].keys())
    df = pd.DataFrame.from_dict(raw_data, orient='columns')
    df = df[order]
    end = time.time()
    print('loaded {} lines of data into a df in {} seconds'.format(len(df), end-start))
    
    #
    start = time.time()
    filename = os.path.basename(file)
    name = filename[:filename.find('.')] + '_df.pkl'
    if(filename == 'review.json'):
        save_as_pickled_object(df, '../data/review_df.pkl')
    else:
        df.to_pickle('../data/' + name)
    end = time.time()
    print('{} has been converted to {} in {} seconds'.format(filename, name, end-start))

    return df

# %%
# This is the folder path for your yelp database files
folder = '../data/yelp_dataset/'

#reads in each .json file and turns it into a pickle file for faster and easier access
start = time.time()
json_file_list = []
for file in os.listdir(folder):
    if file.endswith(".json"):
        json_file_list.append(folder+file)
        print('found ' + file)               

for file in json_file_list:
    print('\nloading {}...'.format(file))
    load_dataset(file)
end = time.time()
    
print('\nFinished loading all json files! This took {} seconds.'.format(end-start))
# Out:
# found business.json
# found review_sample.json
# found user.json
# found checkin.json
# found tip.json
# found review.json
# found photo.json
#
# loading ../data/yelp_dataset/business.json...
# loaded in 192609 lines of data into a list in 264.7689700126648 seconds
# loaded 192609 lines as a df in 1.0468401908874512 seconds
# business.json has been converted to business_df.pkl in 2.9696381092071533 seconds
# loading ../data/yelp_dataset/review_sample.json...
# loaded in 5000 lines of data into a list in 0.04626607894897461 seconds
# loaded 5000 lines as a df in 0.03955817222595215 seconds
# review_sample.json has been converted to review_sample_df.pkl in 0.015414953231811523 seconds
# loading ../data/yelp_dataset/user.json...
# loaded in 1637138 lines of data into a list in 105.56039309501648 seconds
# loaded 1637138 lines as a df in 28.80335807800293 seconds
# user.json has been converted to user_df.pkl in 19.84369993209839 seconds
# loading ../data/yelp_dataset/checkin.json...
# loaded in 161950 lines of data into a list in 1.5280051231384277 seconds
# loaded 161950 lines as a df in 0.25268006324768066 seconds
# checkin.json has been converted to checkin_df.pkl in 0.9046452045440674 seconds
# loading ../data/yelp_dataset/tip.json...
# loaded in 1223094 lines of data into a list in 5.613691091537476 seconds
# loaded 1223094 lines as a df in 3.0895118713378906 seconds
# tip.json has been converted to tip_df.pkl in 2.400291919708252 seconds
# loading ../data/yelp_dataset/review.json...
# loaded in 6685900 lines of data into a list in 182.25465869903564 seconds
# loaded 6685900 lines as a df in 175.36436700820923 seconds
# review.json has been converted to review_df.pkl in 249.09662890434265 seconds
# loading ../data/yelp_dataset/photo.json...
# loaded in 200000 lines of data into a list in 1.0332450866699219 seconds
# loaded 200000 lines as a df in 0.4679901599884033 seconds
# photo.json has been converted to photo_df.pkl in 0.2490062713623047 seconds
# Finished loading all json files! This took 1220.9538009166718 seconds.

# %% [markdown]
# ## See Schema of each table in the dataset

# %%
for file in json_file_list:
    raw_data = []
    with open(file) as f:
        for line in f:
            raw_data.append(json.loads(line))
    print('printing schema for {}, {} rows'.format(file, len(raw_data)))
    schema = list(raw_data[0].keys())
    print(schema)
# Out:
# printing schema for ../data/yelp_dataset/business.json, 192609 rows
# ['business_id', 'name', 'address', 'city', 'state', 'postal_code', 'latitude', 'longitude', 'stars', 'review_count', 'is_open', 'attributes', 'categories', 'hours']
# printing schema for ../data/yelp_dataset/review_sample.json, 5000 rows
# ['review_id', 'user_id', 'business_id', 'stars', 'useful', 'funny', 'cool', 'text', 'date']
# printing schema for ../data/yelp_dataset/user.json, 1637138 rows
# ['user_id', 'name', 'review_count', 'yelping_since', 'useful', 'funny', 'cool', 'elite', 'friends', 'fans', 'average_stars', 'compliment_hot', 'compliment_more', 'compliment_profile', 'compliment_cute', 'compliment_list', 'compliment_note', 'compliment_plain', 'compliment_cool', 'compliment_funny', 'compliment_writer', 'compliment_photos']
# printing schema for ../data/yelp_dataset/checkin.json, 161950 rows
# ['business_id', 'date']
# printing schema for ../data/yelp_dataset/tip.json, 1223094 rows
# ['user_id', 'business_id', 'text', 'date', 'compliment_count']
# printing schema for ../data/yelp_dataset/review.json, 6685900 rows
# ['review_id', 'user_id', 'business_id', 'stars', 'useful', 'funny', 'cool', 'text', 'date']
# printing schema for ../data/yelp_dataset/photo.json, 200000 rows
# ['caption', 'photo_id', 'business_id', 'label']

# %% [markdown]
# ## Only interested in 2 tables:
# * review.json
# * business.json

# %%
business_df = pd.read_pickle('../data/business_df.pkl')
print(business_df.shape)
business_df.head(2)
# Out:
# (192609, 14)
#               business_id                        name  \
# 0  1SWheh84yJXfytovILXOAQ  Arizona Biltmore Golf Club
# 1  QXAEGFB4oINsVuTFxEYKFQ  Emerald Chinese Restaurant
#
#                        address         city state postal_code   latitude  \
# 0  2818 E Camino Acequia Drive      Phoenix    AZ       85016  33.522143
# 1         30 Eglinton Avenue W  Mississauga    ON     L5R 3E7  43.605499
#
#     longitude  stars  review_count  is_open  \
# 0 -112.018481    3.0             5        0
# 1  -79.652289    2.5           128        1
#
#                                           attributes  \
# 0                           {'GoodForKids': 'False'}
# 1  {'RestaurantsReservations': 'True', 'GoodForMe...
#
#                                           categories  \
# 0                                  Golf, Active Life
# 1  Specialty Food, Restaurants, Dim Sum, Imported...
#
#                                                hours
# 0                                               None
# 1  {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...

# %%
user_df = pd.read_pickle('../data/user_df.pkl')
print(user_df.shape)
user_df.head(2)
# Out:
# (1637138, 22)
#                   user_id    name  review_count        yelping_since  useful  \
# 0  l6BmjZMeQD3rDxWUbiAiow  Rashmi            95  2013-10-08 23:11:33      84
# 1  4XChL029mKr5hydo79Ljxg   Jenna            33  2013-02-21 22:29:06      48
#
#    funny  cool           elite  \
# 0     17    25  2015,2016,2017
# 1     22    16
#
#                                              friends  fans  average_stars  \
# 0  c78V-rj8NQcQjOI8KP3UEA, alRMgPcngYSCJ5naFRBz5g...     5           4.03
# 1  kEBTgDvFX754S68FllfCaA, aB2DynOxNOJK9st2ZeGTPg...     4           3.63
#
#    compliment_hot  compliment_more  compliment_profile  compliment_cute  \
# 0               2                0                   0                0
# 1               1                0                   0                0
#
#    compliment_list  compliment_note  compliment_plain  compliment_cool  \
# 0                0                1                 1                1
# 1                0                0                 0                1
#
#    compliment_funny  compliment_writer  compliment_photos
# 0                 1                  2                  0
# 1                 1                  0                  0

# %%
checkin_df = pd.read_pickle('../data/checkin_df.pkl')
print(checkin_df.shape)
checkin_df.head(2)
# Out:
# (161950, 2)
#               business_id                                               date
# 0  --1UhMGODdWsrMastO9DZw  2016-04-26 19:49:16, 2016-08-30 18:36:57, 2016...
# 1  --6MefnULPED_I942VcFNA  2011-06-04 18:22:23, 2011-07-23 23:51:33, 2012...

# %%
tip_df = pd.read_pickle('../data/tip_df.pkl')
print(tip_df.shape)
tip_df.head(2)
# Out:
# (1223094, 5)
#                   user_id             business_id  \
# 0  UPw5DWs_b-e2JRBS-t37Ag  VaKXUpmWTTWDKbpJ3aQdMw
# 1  Ocha4kZBHb4JK0lOWvE0sg  OPiPeoJiv92rENwbq76orA
#
#                                                 text                 date  \
# 0  Great for watching games, ufc, and whatever el...  2014-03-27 03:51:24
# 1  Happy Hour 2-4 daily with 1/2 price drinks and...  2013-05-25 06:00:56
#
#    compliment_count
# 0                 0
# 1                 0

# %%
review_df = pd.read_pickle('../data/review_df.pkl')
print(review_df.shape)
review_df.head(2)
# Out:
# (6685900, 9)
#                 review_id                 user_id             business_id  \
# 0  Q1sbwvVQXV2734tPgoKj4Q  hG7b0MtEbXx5QzbzE6C_VA  ujmEBvifdJM6h6RLv4wQIg
# 1  GJXCdrto3ASJOqKeVWPi6Q  yXQM5uF2jS6es16SJzNHfg  NZnhc2sEQy3RmzKTZnqtwQ
#
#    stars  useful  funny  cool  \
# 0    1.0       6      1     0
# 1    5.0       0      0     0
#
#                                                 text                 date
# 0  Total bill for this horrible service? Over $8G...  2013-05-07 04:34:36
# 1  I *adore* Travis at the Hard Rock's new Kelly ...  2017-01-14 21:30:33

# %%
photo_df = pd.read_pickle('../data/photo_df.pkl')
print(photo_df.shape)
photo_df.head(2)
# Out:
# (200000, 4)
#   caption                photo_id             business_id   label
# 0          MllA1nNpcp1kDteVg6OGUw  rcaPajgKOJC2vo_l3xa42A  inside
# 1          YjxBE88Bf6CmTEF2LP1UNA  Kn23LDd740SBVJ7mum0fwg  inside

# %%
min(review_df['date']), max(review_df['date'])
# Out:
# ('2004-10-12 10:13:32', '2018-11-14 18:13:26')

# %% [markdown]
# ## Create Combined DF
# add new computed columns and drop the columns used to create them

# %% [markdown]
# ### exploring and re-creating 'user_df'
#
# adds likes, compliments, elite columns into one column that is more readable for use in EDA/modelling

# %%
user_df['likes'] = user_df['useful'] + user_df['funny']+ user_df['cool']
user_df['compliments'] = user_df['compliment_hot'] + user_df['compliment_more']+ user_df['compliment_profile']+ user_df['compliment_cute']+ user_df['compliment_list']+ user_df['compliment_note']+ user_df['compliment_plain']+ user_df['compliment_cool']+ user_df['compliment_funny']+ user_df['compliment_writer']+ user_df['compliment_photos']
user_df['elite_years'] = user_df['elite'].apply(lambda x: len(x.split(',')))
user_df = user_df.drop(['useful', 'funny', 'cool', 'elite', 'compliment_hot', 'compliment_more', 'compliment_profile', 'compliment_cute', 'compliment_list', 'compliment_note', 'compliment_plain', 'compliment_cool', 'compliment_funny', 'compliment_writer', 'compliment_photos'], axis=1)
user_df.head()
# Out:
#                   user_id    name  review_count        yelping_since  \
# 0  l6BmjZMeQD3rDxWUbiAiow  Rashmi            95  2013-10-08 23:11:33
# 1  4XChL029mKr5hydo79Ljxg   Jenna            33  2013-02-21 22:29:06
# 2  bc8C_eETBWL0olvFSJJd0w   David            16  2013-10-04 00:16:10
# 3  dD0gZpBctWGdWo9WlGuhlA  Angela            17  2014-05-22 15:57:30
# 4  MM4RJAeH6yuaN8oZDSt0RA   Nancy           361  2013-10-23 07:02:50
#
#                                              friends  fans  average_stars  \
# 0  c78V-rj8NQcQjOI8KP3UEA, alRMgPcngYSCJ5naFRBz5g...     5           4.03
# 1  kEBTgDvFX754S68FllfCaA, aB2DynOxNOJK9st2ZeGTPg...     4           3.63
# 2  4N-HU_T32hLENLntsNKNBg, pSY2vwWLgWfGVAAiKQzMng...     0           3.71
# 3  RZ6wS38wnlXyj-OOdTzBxA, l5jxZh1KsgI8rMunm-GN6A...     5           4.85
# 4  mbwrZ-RS76V1HoJ0bF_Geg, g64lOV39xSLRZO0aQQ6DeQ...    39           4.08
#
#    likes  compliments  elite_years
# 0    126            8            3
# 1     86            3            1
# 2     46            1            1
# 3     48            4            1
# 4   2058          293            4

# %% [markdown]
# ### exploring and re-creating 'business_df'

# %%
business_df.categories = business_df.categories.fillna('[]') # businesses without categories get a null category
business_df.categories = business_df['categories'].apply(lambda x: x.split(', '))
business_df.head()
# Out:
#               business_id                             name  \
# 0  1SWheh84yJXfytovILXOAQ       Arizona Biltmore Golf Club
# 1  QXAEGFB4oINsVuTFxEYKFQ       Emerald Chinese Restaurant
# 2  gnKjwL_1w79qoiV3IC_xQQ      Musashi Japanese Restaurant
# 3  xvX2CttrVhyG2z1dFg_0xw  Farmers Insurance - Paul Lorenz
# 4  HhyxOkGAM07SRYtlQ4wMFQ              Queen City Plumbing
#
#                           address         city state postal_code   latitude  \
# 0     2818 E Camino Acequia Drive      Phoenix    AZ       85016  33.522143
# 1            30 Eglinton Avenue W  Mississauga    ON     L5R 3E7  43.605499
# 2       10110 Johnston Rd, Ste 15    Charlotte    NC       28210  35.092564
# 3   15655 W Roosevelt St, Ste 237     Goodyear    AZ       85338  33.455613
# 4  4209 Stuart Andrew Blvd, Ste F    Charlotte    NC       28217  35.190012
#
#     longitude  stars  review_count  is_open  \
# 0 -112.018481    3.0             5        0
# 1  -79.652289    2.5           128        1
# 2  -80.859132    4.0           170        1
# 3 -112.395596    5.0             3        1
# 4  -80.887223    4.0             4        1
#
#                                           attributes  \
# 0                           {'GoodForKids': 'False'}
# 1  {'RestaurantsReservations': 'True', 'GoodForMe...
# 2  {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...
# 3                                               None
# 4  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...
#
#                                           categories  \
# 0                                [Golf, Active Life]
# 1  [Specialty Food, Restaurants, Dim Sum, Importe...
# 2                [Sushi Bars, Restaurants, Japanese]
# 3                    [Insurance, Financial Services]
# 4  [Plumbing, Shopping, Local Services, Home Serv...
#
#                                                hours
# 0                                               None
# 1  {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...
# 2  {'Monday': '17:30-21:30', 'Wednesday': '17:30-...
# 3  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...
# 4  {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...

# %% [markdown]
# #### 788841 category listings

# %%
# converts categories column into one list of all categories

category_lst = []
for category in business_df['categories']:
    category_lst.extend(category)
    
len(category_lst)
# Out:
# 788841

# %% [markdown]
# #### there are 1301 categories !!!!
#
# #### this is <b>too</b> many, let's only keep 'Restaurants' category for next steps to simplify EDA/modelling
#
# #### notes:
# * briefly looking at the categories and business_df, there are restaurant subtypes (e.g. chinese, seafood, sushi bars) but they also have a 'restaurant' category appended to them
# * certain 'food' category types (e.g. bakery) do not have a 'restaurant category type, these would be excluded from our final dataset for simplification

# %%
len(Counter(category_lst))
# Out:
# 1301

# %%
# top 20 categories by frequency count

# Counter(category_lst).items()
sorted(Counter(category_lst).items(), key=lambda x: x[1], reverse=True)[:20]
# Out:
# [('Restaurants', 59371),
#  ('Shopping', 31878),
#  ('Food', 29989),
#  ('Home Services', 19729),
#  ('Beauty & Spas', 19370),
#  ('Health & Medical', 17171),
#  ('Local Services', 13932),
#  ('Automotive', 13203),
#  ('Nightlife', 13095),
#  ('Bars', 11341),
#  ('Event Planning & Services', 10371),
#  ('Active Life', 9521),
#  ('Fashion', 7798),
#  ('Sandwiches', 7332),
#  ('Coffee & Tea', 7321),
#  ('Fast Food', 7257),
#  ('American (Traditional)', 7107),
#  ('Hair Salons', 6955),
#  ('Pizza', 6804),
#  ('Home & Garden', 6489)]

# %%
Counter(category_lst)['Restaurants']
# Out:
# 59371

# %%
business_df['restaurant?'] = business_df['categories'].apply(lambda x: True if 'Restaurants' in x else False)
business_df.head()
# Out:
#               business_id                             name  \
# 0  1SWheh84yJXfytovILXOAQ       Arizona Biltmore Golf Club
# 1  QXAEGFB4oINsVuTFxEYKFQ       Emerald Chinese Restaurant
# 2  gnKjwL_1w79qoiV3IC_xQQ      Musashi Japanese Restaurant
# 3  xvX2CttrVhyG2z1dFg_0xw  Farmers Insurance - Paul Lorenz
# 4  HhyxOkGAM07SRYtlQ4wMFQ              Queen City Plumbing
#
#                           address         city state postal_code   latitude  \
# 0     2818 E Camino Acequia Drive      Phoenix    AZ       85016  33.522143
# 1            30 Eglinton Avenue W  Mississauga    ON     L5R 3E7  43.605499
# 2       10110 Johnston Rd, Ste 15    Charlotte    NC       28210  35.092564
# 3   15655 W Roosevelt St, Ste 237     Goodyear    AZ       85338  33.455613
# 4  4209 Stuart Andrew Blvd, Ste F    Charlotte    NC       28217  35.190012
#
#     longitude  stars  review_count  is_open  \
# 0 -112.018481    3.0             5        0
# 1  -79.652289    2.5           128        1
# 2  -80.859132    4.0           170        1
# 3 -112.395596    5.0             3        1
# 4  -80.887223    4.0             4        1
#
#                                           attributes  \
# 0                           {'GoodForKids': 'False'}
# 1  {'RestaurantsReservations': 'True', 'GoodForMe...
# 2  {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...
# 3                                               None
# 4  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...
#
#                                           categories  \
# 0                                [Golf, Active Life]
# 1  [Specialty Food, Restaurants, Dim Sum, Importe...
# 2                [Sushi Bars, Restaurants, Japanese]
# 3                    [Insurance, Financial Services]
# 4  [Plumbing, Shopping, Local Services, Home Serv...
#
#                                                hours  restaurant?
# 0                                               None        False
# 1  {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...         True
# 2  {'Monday': '17:30-21:30', 'Wednesday': '17:30-...         True
# 3  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...        False
# 4  {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...        False

# %%
print('Yelp business dataset has {:,} unique businesses'.format(business_df.shape[0]))
restaurant_df = business_df[business_df['restaurant?']==True]
restaurant_df = restaurant_df.drop(['restaurant?'], axis=1)
restaurant_df = restaurant_df.reset_index(drop=True)
print('Removing businesses with no "Restaurants" category, there are {:,} "Restaurants" left'.format(restaurant_df.shape[0]))
print('{:,} or {:.2%} non-Restaurants were removed with this process'.format(business_df.shape[0]-restaurant_df.shape[0], (business_df.shape[0]-restaurant_df.shape[0])/business_df.shape[0]))
# Out:
# Yelp business dataset has 192,609 unique businesses
# Removing businesses with no "Restaurants" category, there are 59,371 "Restaurants" left
# 133,238 or 69.18% non-Restaurants were removed with this process

# %%
restaurant_df.head(2)
# Out:
#               business_id                         name  \
# 0  QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant
# 1  gnKjwL_1w79qoiV3IC_xQQ  Musashi Japanese Restaurant
#
#                      address         city state postal_code   latitude  \
# 0       30 Eglinton Avenue W  Mississauga    ON     L5R 3E7  43.605499
# 1  10110 Johnston Rd, Ste 15    Charlotte    NC       28210  35.092564
#
#    longitude  stars  review_count  is_open  \
# 0 -79.652289    2.5           128        1
# 1 -80.859132    4.0           170        1
#
#                                           attributes  \
# 0  {'RestaurantsReservations': 'True', 'GoodForMe...
# 1  {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...
#
#                                           categories  \
# 0  [Specialty Food, Restaurants, Dim Sum, Importe...
# 1                [Sushi Bars, Restaurants, Japanese]
#
#                                                hours
# 0  {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...
# 1  {'Monday': '17:30-21:30', 'Wednesday': '17:30-...

# %% [markdown]
# ### Create Master DF
#
# The is the combined dataframe of businesses info (only restaurants), user info, and review info

# %%
master_df = restaurant_df.merge(review_df, left_on='business_id', right_on='business_id').merge(user_df, left_on='user_id', right_on='user_id')

master_df.head()
# Out:
#               business_id                      name_x  \
# 0  QXAEGFB4oINsVuTFxEYKFQ  Emerald Chinese Restaurant
# 1  NX1281ugzs2navHAX5X9cQ                  Cha Me Cha
# 2  5H4coiGpvG3XdnU1Nde2xQ          Keung's Restaurant
# 3  SvMBtzXfE-3H5pxoR7VD3w             Kenny's Gourmet
# 4  PFAvETr4Vf6UY548TWvhFA      Koi Sakana Ramen House
#
#                                 address           city state postal_code  \
# 0                  30 Eglinton Avenue W    Mississauga    ON     L5R 3E7
# 1         8333 Kennedy Road, Suite 1078        Markham    ON     L3R 1J5
# 2                     8380 Kennedy Road        Markham    ON     L3R 0W4
# 3  1480 Major Mackenzie Drive E, Unit 7  Richmond Hill    ON         L3R
# 4               360 Highway 7 E, Unit 3  Richmond Hill    ON     L4B 3Y7
#
#     latitude  longitude  stars_x  review_count_x  is_open  \
# 0  43.605499 -79.652289      2.5             128        1
# 1  43.856327 -79.303884      3.0             293        1
# 2  43.860726 -79.304713      3.0              60        1
# 3  43.883345 -79.388160      3.0              15        0
# 4  43.841523 -79.397015      3.5             148        1
#
#                                           attributes  \
# 0  {'RestaurantsReservations': 'True', 'GoodForMe...
# 1  {'OutdoorSeating': 'False', 'RestaurantsPriceR...
# 2  {'Alcohol': 'u'none'', 'BusinessParking': '{'g...
# 3  {'RestaurantsReservations': 'True', 'BikeParki...
# 4  {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
#
#                                           categories  \
# 0  [Specialty Food, Restaurants, Dim Sum, Importe...
# 1  [Bubble Tea, Food, Restaurants, Taiwanese, Cof...
# 2                             [Restaurants, Chinese]
# 3                             [Restaurants, Chinese]
# 4     [Restaurants, Canadian (New), Japanese, Ramen]
#
#                                                hours               review_id  \
# 0  {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...  6W0MQHmasK0IsaoDo4bmkw
# 1  {'Monday': '12:0-0:0', 'Tuesday': '12:0-0:0', ...  wbRQarYt_jBHNleOr0e1ng
# 2  {'Monday': '11:0-0:0', 'Tuesday': '11:0-0:0', ...  4xF9XB58CCuOcOv1lZJiiw
# 3                                               None  naq8WG94TqTeE4E__Q3x7A
# 4  {'Tuesday': '17:0-21:0', 'Wednesday': '17:0-21...  CeNglOZFNkOYP8Gx3CIxRw
#
#                   user_id  stars_y  useful  funny  cool  \
# 0  2K62MJ4CJ19L8Tp5pRfjfQ      3.0       3      2     0
# 1  2K62MJ4CJ19L8Tp5pRfjfQ      4.0       1      0     0
# 2  2K62MJ4CJ19L8Tp5pRfjfQ      3.0       0      0     0
# 3  2K62MJ4CJ19L8Tp5pRfjfQ      3.0       0      0     0
# 4  2K62MJ4CJ19L8Tp5pRfjfQ      5.0       2      1     1
#
#                                                 text                 date  \
# 0  My girlfriend and I went for dinner at Emerald...  2017-01-27 21:54:30
# 1  We decided to make a stop at Cha Me Cha for a ...  2018-08-20 21:38:43
# 2  I went to Keung's restaurant over the weekend ...  2014-12-02 23:45:52
# 3  I visited Kenny's with some friend to eat lunc...  2015-01-19 22:09:07
# 4  I went to Koi Sakana last Saturday, my second ...  2016-02-19 02:08:29
#
#   name_y  review_count_y        yelping_since  \
# 0  David              57  2014-11-27 22:36:00
# 1  David              57  2014-11-27 22:36:00
# 2  David              57  2014-11-27 22:36:00
# 3  David              57  2014-11-27 22:36:00
# 4  David              57  2014-11-27 22:36:00
#
#                                              friends  fans  average_stars  \
# 0  ZJfwkdJMex21dGHfQ3YgTg, 603oDa3dGdJyfkq2RoH2Dw...     1            3.3
# 1  ZJfwkdJMex21dGHfQ3YgTg, 603oDa3dGdJyfkq2RoH2Dw...     1            3.3
# 2  ZJfwkdJMex21dGHfQ3YgTg, 603oDa3dGdJyfkq2RoH2Dw...     1            3.3
# 3  ZJfwkdJMex21dGHfQ3YgTg, 603oDa3dGdJyfkq2RoH2Dw...     1            3.3
# 4  ZJfwkdJMex21dGHfQ3YgTg, 603oDa3dGdJyfkq2RoH2Dw...     1            3.3
#
#    likes  compliments  elite_years
# 0    100           16            2
# 1    100           16            2
# 2    100           16            2
# 3    100           16            2
# 4    100           16            2

# %% [markdown]
# ### Calculate data loss from removing non-restaurants

# %%
master_df.shape
# Out:
# (4201684, 31)

# %%
review_df.shape
# Out:
# (6685900, 9)

# %%
print('review dataset had {:,} reviews'.format(review_df.shape[0]))
print('master dataframe has {:,} reviews'.format(master_df.shape[0]))
print('there is a loss of {:,} or {:.2%} reviews'.format(review_df.shape[0]-master_df.shape[0], (review_df.shape[0]-master_df.shape[0])/review_df.shape[0]))
# Out:
# review dataset had 6,685,900 reviews
# master dataframe has 4,201,684 reviews
# there is a loss of 2,484,216 or 37.16% reviews

# %%
unique_users_in_master_df = len(master_df.groupby('user_id')['name_y'].nunique())

print('user dataset had {:,} users'.format(user_df.shape[0]))
print('master dataframe has {:,} users'.format(unique_users_in_master_df))
print('there is a loss of {:,} or {:.2%} reviews'.format(user_df.shape[0]-unique_users_in_master_df, (user_df.shape[0]-unique_users_in_master_df)/user_df.shape[0]))
# Out:
# user dataset had 1,637,138 users
# master dataframe has 1,148,098 users
# there is a loss of 489,040 or 29.87% reviews

# %% [markdown]
# ### Save master_df to pickle

# %%
save_as_pickled_object(master_df,'../data/master_df.pkl')
