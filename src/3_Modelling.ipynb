# %% [markdown]
# # Modelling
#
# Finding the ideal model for recommending restuarants to users

# %%
import os
import time
import json
import pickle
from collections import Counter
import collections

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# import databricks.koalas as ks

import pyspark
from pyspark.sql import SparkSession
import pandas as pd

# Setup a SparkSession
spark = SparkSession.builder.getOrCreate()

import pandas_profiling
# df.profile_report(style={'full_width':True})
# df.profile_report(title='Pandas Profiling Report')

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline
plt.style.use('seaborn')
font = {'size':16}
import seaborn as sns

from sklearn.metrics import mean_absolute_error

import surprise
from surprise import Dataset
from surprise import Reader
from surprise.model_selection import cross_validate
from surprise.model_selection import GridSearchCV
from surprise import KNNBasic, KNNWithMeans, KNNWithZScore, KNNBaseline
from surprise import SVD, SVDpp, NMF
from surprise import accuracy
from surprise import SlopeOne, CoClustering
from surprise.model_selection import train_test_split

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import warnings
warnings.simplefilter('ignore')

# %%
def notify(title, text):
    os.system("""
              osascript -e 'display notification "{}" with title "{}"'
              """.format(text, title))

notify("Test Title", "Heres an alert")

# %% [markdown]
# ## Reading in AZNV dataframe

# %%
AZNV_df = pd.read_pickle('../data/AZNV_df.p')
print(AZNV_df.shape)
AZNV_df.head(2)
# Out:
# (1818490, 32)
#               business_id                       name_x                address  \
# 0  vx4YAA02Qz6khRD1fZ1MFA               Ping Pang Pong     4000 W Flamingo Rd
# 1  glTBzDHv9wNhEsZa4bQrOA  CatHouse Boutique Nightclub  3900 Las Vegas Blvd S
#
#         city state postal_code   latitude   longitude  stars_x  \
# 0  Las Vegas    NV       89103  36.116901 -115.193512      3.5
# 1  Las Vegas    NV       89119  36.094822 -115.173216      3.0
#
#    review_count_x  is_open                                         attributes  \
# 0            1005        1  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 1             178        0  {'OutdoorSeating': 'False', 'BusinessAcceptsCr...
#
#                                           categories  \
# 0  [Cantonese, Seafood, Dim Sum, Restaurants, Chi...
# 1  [Restaurants, Nightlife, Lounges, American (Ne...
#
#                                                hours               review_id  \
# 0  {'Monday': '10:0-3:0', 'Tuesday': '10:0-3:0', ...  FwiJ7DQ3a9cBwp1OYlP5VA
# 1  {'Monday': '17:0-4:0', 'Tuesday': '17:0-4:0', ...  7ynnTyXiuIWHDkktHsdm4Q
#
#                   user_id  stars_y  useful  funny  cool  \
# 0  A0kENtCCoVT3m7T35zb2Vg      2.0       0      0     0
# 1  A0kENtCCoVT3m7T35zb2Vg      2.0       1      1     0
#
#                                                 text                 date  \
# 0  There are so many good reviews of this place o...  2010-04-02 20:37:54
# 1  Restaurant-only review; based on that, they wo...  2009-02-16 14:53:11
#
#       name_y  review_count_y        yelping_since  \
# 0  Anastasia             348  2009-02-15 16:45:34
# 1  Anastasia             348  2009-02-15 16:45:34
#
#                                              friends  fans  average_stars  \
# 0  BBY1Alonk5V0OLgk_G0rNQ, TY7QgNKJEhvo1zCULlT9Rg...     9           3.66
# 1  BBY1Alonk5V0OLgk_G0rNQ, TY7QgNKJEhvo1zCULlT9Rg...     9           3.66
#
#    likes  compliments  elite_years  hotel?
# 0    619           38            3       0
# 1    619           38            3       0

# %%
np.mean(AZNV_df['stars_x'])
# Out:
# 3.7818712228277307

# %% [markdown]
# ### Create numerical features for IDs

# %%
user_labels, user_uniques = pd.factorize(AZNV_df['user_id'])
business_labels, business_uniques = pd.factorize(AZNV_df['business_id'])

AZNV_df['userid'] = user_labels
AZNV_df['businessid'] = business_labels

# %% [markdown]
# ### Create pandas and spark DF for recommender models

# %%
pandas_df = AZNV_df[['userid', 'businessid', 'stars_y']]
pandas_df = pandas_df.rename(columns={"businessid": "restaurantid", "stars_y":"rating"})

pandas_df.head()
# Out:
#    userid  restaurantid  rating
# 0       0             0     2.0
# 1       0             1     2.0
# 2       0             2     1.0
# 3       0             3     4.0
# 4       0             4     5.0

# %%
pandas_df.to_pickle('../data/model_pandas_df.p')

# %%
pandas_df = pd.read_pickle('../data/model_pandas_df.p')
pandas_df.head(2)
# Out:
#    userid  restaurantid  rating
# 0       0             0     2.0
# 1       0             1     2.0

# %%
spark_df = spark.createDataFrame(pandas_df)

# %% [markdown]
# ## ALS Model - Base Model
#
# Train ALS model using np.mean of ratings

# %%
train, test = spark_df.randomSplit([0.8, 0.2], seed=0)

train.show(5)

train.count()
# Out:
# +------+------------+------+
# |userid|restaurantid|rating|
# +------+------------+------+
# |     0|           1|   2.0|
# |     0|           2|   1.0|
# |     0|           4|   5.0|
# |     0|           6|   5.0|
# |     0|           7|   3.0|
# +------+------------+------+
# only showing top 5 rows
# 1455147

# %%
train_with_mean = train.toPandas()
train_with_mean['rating'] = np.mean(train_with_mean['rating'])
train_with_mean = spark.createDataFrame(train_with_mean)
train_with_mean.show(2)
# Out:
# +------+------------+------------------+
# |userid|restaurantid|            rating|
# +------+------------+------------------+
# |     0|           1|3.7893498045214677|
# |     0|           2|3.7893498045214677|
# +------+------------+------------------+
# only showing top 2 rows

# %%
from pyspark.ml.recommendation import ALS
als_model = ALS(
    itemCol='restaurantid',
    userCol='userid',
    ratingCol='rating',
    nonnegative=True,    
    regParam=0.1,
    rank=10) 

recommender = als_model.fit(train_with_mean)

print('ALS model has been fitted on train_with_mean data.')
# Out:
# ALS model has been fitted on train_with_mean data.

# %%
# look at a random prediction

data = [(0, 3)]
columns = ('userid', 'restaurantid')
one_row_spark_df = spark.createDataFrame(data, columns)
user_factor_df = recommender.userFactors.filter('id = 1')
item_factor_df = recommender.itemFactors.filter('id = 100')
user_factors = user_factor_df.collect()[0]['features']
item_factors = item_factor_df.collect()[0]['features']
recommender.transform(one_row_spark_df).show()
# Out:
# +------+------------+----------+
# |userid|restaurantid|prediction|
# +------+------------+----------+
# |     0|           3| 3.6294148|
# +------+------------+----------+

# %%
predictions = recommender.transform(test)
predictions.describe().show()
# Out:
# +-------+-----------------+------------------+------------------+----------+
# |summary|           userid|      restaurantid|            rating|prediction|
# +-------+-----------------+------------------+------------------+----------+
# |  count|           363343|            363343|            363343|    363343|
# |   mean|67019.54313692571| 4357.848828792628|3.7901789768896057|       NaN|
# | stddev|56886.59800722874|3628.5879309853876|1.3181072931108382|       NaN|
# |    min|                0|                 0|               1.0| 2.9763389|
# |    max|           203358|             14796|               5.0|       NaN|
# +-------+-----------------+------------------+------------------+----------+

# %%
# Dump the predictions to Pandas DataFrames to make our final calculations easier
predictions_df = predictions.toPandas()
train_df = train.toPandas()

# %%
# Fill any missing values with the mean rating
predictions_df = predictions.toPandas().fillna(train_df['rating'].mean())

# %%
# Calculate Root Mean Squared Error (RMSE)

predictions_df['squared_error'] = (predictions_df['rating'] - predictions_df['prediction'])**2

rmse = np.sqrt(sum(predictions_df['squared_error']) / len(predictions_df))

print('RMSE of base (train data with mean): {}'.format(rmse))
# Out:
# RMSE of base (train data with mean): 1.3274137815483629

# %%
# Calculate Mean Absolute Error (MAE)

y_true = predictions_df['rating']
y_pred = predictions_df['prediction']
mae = mean_absolute_error(y_true, y_pred)

print('MAE of base (train data with mean): {}'.format(mae))
# Out:
# MAE of base (train data with mean): 1.141648958873738

# %% [markdown]
# ### RMSE 1.3274 is the score to beat!
#
# Using RMSE because it punishes error more highly than MAE

# %% [markdown]
# ## ALS on train dataset

# %%
from pyspark.ml.recommendation import ALS
als_model = ALS(
    itemCol='restaurantid',
    userCol='userid',
    ratingCol='rating',
    nonnegative=True,    
    regParam=0.1,
    rank=10) 

recommender = als_model.fit(train)

print('ALS model has been fitted on train data.')
# Out:
# ALS model has been fitted on train data.

# %%
predictions = recommender.transform(test)
predictions_df = predictions.toPandas()
train_df = train.toPandas()
predictions_df = predictions.toPandas().fillna(train_df['rating'].mean())

predictions_df['squared_error'] = (predictions_df['rating'] - predictions_df['prediction'])**2

rmse = np.sqrt(sum(predictions_df['squared_error']) / len(predictions_df))

print('RMSE of train: {}'.format(rmse))
# Out:
# RMSE of train: 1.4427868868935185

# %%
predictions_df.head()
# Out:
#    userid  restaurantid  rating  prediction  squared_error
# 0   29054           148     5.0    4.522486       0.228020
# 1   14514           148     3.0    2.615818       0.147596
# 2  122710           148     4.0    3.924699       0.005670
# 3   14958           148     3.0    3.699966       0.489952
# 4  106608           148     3.0    2.643519       0.127078

# %%
# Create array of predictions for violinplot
data = [predictions_df['prediction'][predictions_df['rating'] == rating].values for rating in range(1, 6)]
plt.violinplot(data, range(1,6), showmeans=True, )
plt.xlabel('True Ratings')
plt.ylabel('Predicted Ratings')
plt.title('True vs. ALS Recommender Predicted Ratings')
plt.show();

# %% [markdown]
# ### Model turned out to be worse than the base...

# %% [markdown]
# ## Collaborative Filtering
#
# Item-Item Collaborative Filtering (IBCF) measures the similarity between the items that target users rates/ interacts with and other items
#
# #### Advantages of item-based filtering over user-based filtering :
#
# * Computationally less expensive : When users >> items, It makes sense to use item-based filtering in this case.
# * Item-item is less sparse than user-user matrix
# * A famous example of item-based filtering is <a href = 'https://www.cs.umd.edu/~samir/498/Amazon-Recommendations.pdf'>Amazon’s recommendation engine</a>.

# %% [markdown]
# ## Surprise library
#
# <a href='http://surpriselib.com/'>Surprise library</a> is a great tool for building and analyzing recommender models.
# <br><br>
# Thank you to bmanohar16's work used as reference

# %% [markdown]
# ### Split data into train/test

# %%
pandas_df.shape
# Out:
# (1818490, 3)

# %%
print('Unique Users    :', pandas_df.userid.nunique())
print('Unique Restaurant :', pandas_df.restaurantid.nunique())
print('Unique Ratings  :', pandas_df.rating.nunique())
# Out:
# Unique Users    : 203359
# Unique Restaurant : 14797
# Unique Ratings  : 5

# %%
# Set Rating Scale
reader = Reader(rating_scale=(1, 5))

# Load data with rating scale
data = Dataset.load_from_df(pandas_df, reader)

# %%
trainset, testset = train_test_split(data, test_size=.25, random_state=0)

# %% [markdown]
# ### KNN Basic
#
# computes similiarities between item-item where k=40 (down to 1 if less than 40)

# %%
start = time.time()

sim_options = {'name': 'cosine',
               'user_based': False  # compute  similarities between items
               }
algo = KNNBasic(sim_options=sim_options)

knnbasic_cv = cross_validate(algo, data, cv=5, n_jobs=-1, verbose=True)

end = time.time()
print('\nthis took {:.2f} seconds to run'.format(end-start))
notify("Notification", "Model is complete")
# Out:
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.3620  1.3590  1.3630  1.3586  1.3600  1.3605  0.0017
# MAE (testset)     1.0236  1.0218  1.0249  1.0202  1.0224  1.0226  0.0016
# Fit time          30.83   31.05   30.42   31.61   28.49   30.48   1.07
# Test time         21.81   20.72   22.87   19.97   18.51   20.78   1.50
# this took 235.93 seconds to run

# %% [markdown]
# ### KNNWithMeans
#
# A basic collaborative filtering algorithm, taking into account the mean ratings of each user.
# <br>
# * Using an item-item similiarity measure with k between 1 and 40

# %%
start = time.time()

sim_options = {'name': 'cosine',
               'user_based': False  # compute  similarities between items
               }
algo = KNNWithMeans(sim_options=sim_options)

knnmeans_cv = cross_validate(algo, data, cv=5, n_jobs=-1, verbose=True)

end = time.time()
print('\nthis took {:.2f} seconds to run'.format(end-start))
notify("Notification", "Model is complete")
# Out:
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.2530  1.2540  1.2519  1.2546  1.2522  1.2531  0.0010
# MAE (testset)     0.9448  0.9454  0.9445  0.9462  0.9435  0.9449  0.0009
# Fit time          28.53   31.86   29.81   29.90   29.04   29.83   1.13
# Test time         24.83   21.97   21.61   20.79   20.49   21.94   1.54
#
# this took 230.03 seconds to run
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8d087fdf2c7f> in <module>
#      10 end = time.time()
#      11 print('\nthis took {:.2f} seconds to run'.format(end-start))
# ---> 12 notify(title = 'Model Complete')
#
# NameError: name 'notify' is not defined

# %% [markdown]
# ### KNNWithZScore
#
# A basic collaborative filtering algorithm, taking into account
# the z-score normalization of each user.

# %%
start = time.time()

sim_options = {'name': 'cosine',
               'user_based': False  # compute  similarities between items
               }
algo = KNNWithZScore(sim_options=sim_options)

knnz_cv = cross_validate(algo, data, cv=5, n_jobs=-1, verbose=True)

end = time.time()
print('\nthis took {:.2f} seconds to run'.format(end-start))
notify("Notification", "Model is complete")
# Out:
# Evaluating RMSE, MAE of algorithm KNNWithZScore on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.2524  1.2543  1.2562  1.2551  1.2549  1.2546  0.0012
# MAE (testset)     0.9397  0.9414  0.9441  0.9418  0.9417  0.9417  0.0014
# Fit time          32.71   37.81   36.07   34.22   31.72   34.50   2.21
# Test time         30.26   27.80   26.57   24.80   23.21   26.53   2.43
#
# this took 255.27 seconds to run
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-53fd8f24f981> in <module>
#      10 end = time.time()
#      11 print('\nthis took {:.2f} seconds to run'.format(end-start))
# ---> 12 notify(title = 'Model Complete')
#
# TypeError: notify() missing 2 required positional arguments: 'subtitle' and 'message'

# %% [markdown]
# ### KNNBaseline
#
# A basic collaborative filtering algorithm taking into account a baseline rating.

# %%
start = time.time()

sim_options = {'name': 'cosine',
               'shrinkage': 0,  # no shrinkage
               'user_based': False  # compute  similarities between items
               }
algo = KNNBaseline(sim_options=sim_options)

knn_baseline = cross_validate(algo, data, cv=5, n_jobs=-1, verbose=True)

end = time.time()
print('\nthis took {:.2f} seconds to run'.format(end-start))
notify("Notification", "Model is complete")
# Out:
# Evaluating RMSE, MAE of algorithm KNNBaseline on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.2562  1.2542  1.2526  1.2500  1.2562  1.2538  0.0023
# MAE (testset)     0.9484  0.9472  0.9464  0.9438  0.9486  0.9469  0.0017
# Fit time          32.35   41.32   38.04   34.44   31.50   35.53   3.67
# Test time         37.84   35.46   31.70   25.59   24.23   30.96   5.33
#
# this took 260.60 seconds to run

# %% [markdown]
# ### Matrix Factorization Based Algorithms

# %%
start = time.time()

svd_cv = cross_validate(SVD(), data, cv=5, n_jobs=-1, verbose=True)

end = time.time()
print('\nthis took {:.2f} seconds to run'.format(end-start))
notify("Notification", "Model is complete")
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1934  1.1932  1.1936  1.1928  1.1940  1.1934  0.0004
# MAE (testset)     0.9465  0.9464  0.9477  0.9469  0.9473  0.9470  0.0005
# Fit time          110.08  114.72  112.34  105.94  101.61  108.94  4.67
# Test time         5.15    4.39    3.91    3.82    3.75    4.21    0.52
#
# this took 309.10 seconds to run
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-8b794633d7eb> in <module>
#       5 end = time.time()
#       6 print('\nthis took {:.2f} seconds to run'.format(end-start))
# ----> 7 notify(title = 'Model Complete')
#
# TypeError: notify() missing 2 required positional arguments: 'subtitle' and 'message'

# %%
start = time.time()

svdpp_cv = cross_validate(SVDpp(), data, cv=5, n_jobs=-1, verbose=True)

end = time.time()
print('\nthis took {:.2f} seconds to run'.format(end-start))
notify("Notification", "Model is complete")
# Out:
# Evaluating RMSE, MAE of algorithm SVDpp on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1993  1.1993  1.1989  1.2015  1.1970  1.1992  0.0014
# MAE (testset)     0.9461  0.9471  0.9464  0.9475  0.9454  0.9465  0.0007
# Fit time          1414.89 1418.26 1417.86 1434.24 1408.60 1418.77 8.47
# Test time         31.60   31.58   21.10   19.11   19.95   24.67   5.69
#
# this took 1637.75 seconds to run

# %%
start = time.time()

nmf_cv = cross_validate(NMF(), data, cv=5, n_jobs=-1, verbose=True)

end = time.time()
print('\nthis took {:.2f} seconds to run'.format(end-start))
notify("Notification", "Model is complete")
# Out:
# Evaluating RMSE, MAE of algorithm NMF on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.3246  1.3255  1.3246  1.3258  1.3243  1.3250  0.0006
# MAE (testset)     1.0165  1.0177  1.0169  1.0184  1.0172  1.0173  0.0007
# Fit time          119.38  124.66  126.34  121.72  108.79  120.18  6.18
# Test time         4.10    3.58    3.24    3.13    3.11    3.43    0.38
#
# this took 297.22 seconds to run

# %% [markdown]
# ### Other Collaborative Filtering Algorithms

# %%
start = time.time()

slope_cv = cross_validate(SlopeOne(), data, cv=5, n_jobs=-1, verbose=True)

end = time.time()
print('\nthis took {:.2f} seconds to run'.format(end-start))
notify("Notification", "Model is complete")
# Out:
# Evaluating RMSE, MAE of algorithm SlopeOne on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.3077  1.3083  1.3050  1.3073  1.3042  1.3065  0.0016
# MAE (testset)     0.9811  0.9808  0.9797  0.9803  0.9792  0.9802  0.0007
# Fit time          14.29   14.33   14.50   19.49   15.18   15.56   1.99
# Test time         14.42   14.24   15.73   16.36   16.99   15.55   1.07
#
# this took 223.36 seconds to run

# %%
start = time.time()

coclus_cv = cross_validate(CoClustering(), data, cv=5, n_jobs=-1, verbose=True)

end = time.time()
print('\nthis took {:.2f} seconds to run'.format(end-start))
notify("Notification", "Model is complete")
# Out:
# Evaluating RMSE, MAE of algorithm CoClustering on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.2726  1.2766  1.2751  1.2793  1.2711  1.2749  0.0029
# MAE (testset)     0.9500  0.9534  0.9528  0.9556  0.9505  0.9525  0.0020
# Fit time          36.92   35.66   38.36   35.02   32.95   35.78   1.82
# Test time         3.52    3.17    3.42    3.09    3.17    3.27    0.17
#
# this took 231.57 seconds to run

# %% [markdown]
# ## Comparison of all algorithms on RMSE and MAE

# %% [markdown]
# #### Saving RMSE and MAE scores

# %%
save_scores = [knnbasic_cv, knnmeans_cv, knnz_cv, svd_cv, svdpp_cv, nmf_cv, slope_cv, coclus_cv]
outfile = '../data/RMSE_MAE_scores.png'

with open('outfile', 'wb') as fp:
    pickle.dump(save_scores, fp)

# %% [markdown]
# #### Reading back RMSE and MAE scores

# %%
outfile = '../data/RMSE_MAE_scores.png'

with open ('outfile', 'rb') as fp:
    save_scores = pickle.load(fp)

# %% [markdown]
# #### Show results

# %%
print('Algorithm\t RMSE\t\t MAE')
print('--------------', '\t', '------', '\t', '------')
print('ALS with Means', '\t', round(rmse, 4), '\t', round(mae, 4))
print()
print('KNN Basic', '\t', round(knnbasic_cv['test_rmse'].mean(), 4), '\t', round(knnbasic_cv['test_mae'].mean(), 4))
print('KNN Means', '\t', round(knnmeans_cv['test_rmse'].mean(), 4), '\t', round(knnmeans_cv['test_mae'].mean(), 4))
print('KNN ZScore', '\t', round(knnz_cv['test_rmse'].mean(), 4), '\t', round(knnz_cv['test_mae'].mean(), 4))
print()
print('SVD', '\t\t', round(svd_cv['test_rmse'].mean(), 4), '\t', round(svd_cv['test_mae'].mean(), 4))
print('SVDpp', '\t\t', round(svdpp_cv['test_rmse'].mean(), 4), '\t', round(svdpp_cv['test_mae'].mean(), 4))
print('NMF', '\t\t', round(nmf_cv['test_rmse'].mean(), 4), '\t\t', round(nmf_cv['test_mae'].mean(), 4))
print()
print('SlopeOne', '\t', round(slope_cv['test_rmse'].mean(), 4), '\t', round(slope_cv['test_mae'].mean(), 4))
print('CoClustering', '\t', round(coclus_cv['test_rmse'].mean(), 4), '\t', round(coclus_cv['test_mae'].mean(), 4))
# Out:
# Algorithm	 RMSE		 MAE
# -------------- 	 ------ 	 ------
# ALS with Means 	 1.3274 	 1.1416
#
# KNN Basic 	 1.3605 	 1.0226
# KNN Means 	 1.2531 	 0.9449
# KNN ZScore 	 1.2546 	 0.9417
#
# SVD 		 1.1934 	 0.947
# SVDpp 		 1.1992 	 0.9465
# NMF 		 1.325 		 1.0173
#
# SlopeOne 	 1.3065 	 0.9802
# CoClustering 	 1.2749 	 0.9525

# %% [markdown]
# ### Added KNN Baseline model after restarting notebook
#
# inserting data manually into charts

# %%
print('rmse: ', round(knn_baseline['test_rmse'].mean(), 4))
print('mae: ', round(knn_baseline['test_mae'].mean(), 4))
# Out:
# rmse:  1.2538
# mae:  0.9469

# %%
print('Algorithm\t RMSE\t\t MAE')
print('--------------', '\t', '------', '\t', '------')
print('ALS with Means', '\t', 1.3274, '\t', 1.1416)
print()
print('KNN Basic', '\t', 1.3605, '\t', 1.0226)
print('KNN Means', '\t', 1.2531, '\t', 0.9449)
print('KNN ZScore', '\t', 1.2546, '\t', 0.9417)
print('KNN Baseline', '\t', 1.2538, '\t', 0.9469)
print()
print('SVD', '\t\t', 1.1934, '\t', 0.947)
print('SVDpp', '\t\t', 1.1992, '\t', 0.9465)
print('NMF', '\t\t', 1.325, '\t\t', 1.0173)
print()
print('SlopeOne', '\t', 1.3065, '\t', 0.9802)
print('CoClustering', '\t', 1.2749, '\t', 0.9525)
# Out:
# Algorithm	 RMSE		 MAE
# -------------- 	 ------ 	 ------
# ALS with Means 	 1.3274 	 1.1416
#
# KNN Basic 	 1.3605 	 1.0226
# KNN Means 	 1.2531 	 0.9449
# KNN ZScore 	 1.2546 	 0.9417
# KNN Baseline 	 1.2538 	 0.9469
#
# SVD 		 1.1934 	 0.947
# SVDpp 		 1.1992 	 0.9465
# NMF 		 1.325 		 1.0173
#
# SlopeOne 	 1.3065 	 0.9802
# CoClustering 	 1.2749 	 0.9525

# %% [markdown]
# ### Plotting RMSE / MAE via bar graph

# %%
x_algo = ['KNN Basic', 'KNN Means', 'KNN ZScore', 'KNN Baseline', 'SVD', 'SVDpp', 'NMF', 'SlopeOne', 'CoClustering']
all_algos_cv = [knnbasic_cv, knnmeans_cv, knnz_cv, knn_baseline, ksvd_cv, svdpp_cv, nmf_cv, slope_cv, coclus_cv]

rmse_cv = [round(res['test_rmse'].mean(), 4) for res in all_algos_cv]
mae_cv = [round(res['test_mae'].mean(), 4) for res in all_algos_cv]

# manually adding base score data
x_algo = ['Base [ALS-Means]']+x_algo
rmse_cv = [1.3274]+rmse_cv
mae_cv = [1.1416]+mae_cv

# %%
## hardcoded rmse
x_algo = ['Base [ALS-Means]', 'KNN Basic', 'KNN Means', 'KNN ZScore', 'KNN Baseline', 'SVD', 'SVDpp', 'NMF', 'SlopeOne', 'CoClustering']
rmse_cv = [1.3274, 1.3605, 1.2531, 1.2546, 1.2538, 1.1934, 1.1992, 1.325, 1.3065, 1.2749]

# %%
fig, ax = plt.subplots(1,1, figsize=(12,6))
fig.suptitle('Comparison of Algorithms vs Baseline using RMSE', fontsize=20, verticalalignment='top')
ax.set_title('Root Mean Squared Error (RMSE) "lower is better"', loc='center', fontsize=15)
c = ax.bar(x_algo, rmse_cv, label='RMSE', color='royalblue')
c[0].set_color('tan')
c[5].set_color('#72A651')
c[6].set_color('#72A651')
ax.set_ylim(bottom=1.0, top=max(rmse_cv)+.05)  
ax.set_xlabel('Algorithms', fontsize=15)
ax.set_ylabel('RMSE Value', fontsize=15)
ax.grid(ls='dashed')

# annotate bar graph 1
base0=1.3274
percent0 = [round(n/base0*100,2) for n in rmse_cv]
for i,p in enumerate(ax.patches):
    ax.annotate(str(percent0[i])+'%', (p.get_x() * 1.005, p.get_height() * 1.005))

plt.tight_layout()
fig.subplots_adjust(top=.88)
plt.savefig('../img/rmse_barchart.png', dpi=350, alpha=0)
plt.show();

# %%
# ax[1].set_title('Comparison of Algorithms on MAE', loc='center', fontsize=15)
fig, ax = plt.subplots(1,1, figsize=(12,6))
fig.suptitle('Comparison of Algorithms vs Baseline using MAE', fontsize=20, verticalalignment='top')
ax.set_title('Mean Absolute Error (MAE) - (lower is better)', loc='center', fontsize=15)
c = ax.bar(x_algo, mae_cv, label='MAE', color='navy')
c[0].set_color('tan')
c[3].set_color('lightgreen')
ax.set_ylim(bottom=0.8, top=max(mae_cv)+.05)  
ax.set_xlabel('Algorithms', fontsize=15)
ax.set_ylabel('MAE Value', fontsize=15)
ax.grid(ls='dashed')

# annotate bar graph 2
base1=1.1416
percent1 = [round(n/base1*100,2) for n in mae_cv]
for i,p in enumerate(ax.patches):
    ax.annotate(str(percent1[i])+'%', (p.get_x() * 1.005, p.get_height() * 1.005))

plt.tight_layout()
fig.subplots_adjust(top=.88)
plt.savefig('../img/mae_barchart.png', dpi=350, alpha=0)
plt.show();

# %% [markdown]
# ### Plotting RMSE/MAE via plt.plot

# %%
x_algo = ['KNN Basic', 'KNN Means', 'KNN ZScore', 'SVD', 'SVDpp', 'NMF', 'SlopeOne', 'CoClustering']
all_algos_cv = [knnbasic_cv, knnmeans_cv, knnz_cv, svd_cv, svdpp_cv, nmf_cv, slope_cv, coclus_cv]

rmse_cv = [round(res['test_rmse'].mean(), 4) for res in all_algos_cv]
mae_cv = [round(res['test_mae'].mean(), 4) for res in all_algos_cv]

fig, ax = plt.subplots(2,1, figsize=(10,6))
ax[0].set_title('Comparison of Algorithms RMSE & MAE', loc='center', fontsize=15)
ax[0].plot(x_algo, rmse_cv, label='RMSE', color='darkgreen', marker='o')
# ax[0].set_xlabel('Algorithms', fontsize=15)
ax[0].set_ylabel('RMSE Value', fontsize=15)
ax[0].legend()
ax[0].grid(ls='dashed')

# ax[1].set_title('Comparison of Algorithms on MAE', loc='center', fontsize=15)
ax[1].plot(x_algo, mae_cv, label='MAE', color='navy', marker='o')
ax[1].set_xlabel('Algorithms', fontsize=15)
ax[1].set_ylabel('MAE Value', fontsize=15)
ax[1].legend()
ax[1].grid(ls='dashed')

plt.tight_layout()
plt.savefig('../img/rmse_mae_plotchart.png', dpi=300, transparency=True)
plt.show();

# %% [markdown]
# ## Evaluation Results
#
# <b>Best RMSE</b>: SVD
# <br>
# <b>Best MAE</b>: KNN ZScore
#
# <font color='green'><h2>Winner SVD & SVD++!! </h2></font>
#
# This is according to our metric RMSE.
#
# However SVD and SVDpp both give good results, let's tune the hyperparameters to find the best RMSE score

# %% [markdown]
# ## Tune hyperparameters using GridSearchCV

# %%
svd_param_grid = {'n_epochs': [5, 10], 
                  'lr_all': [0.007, 0.009, 0.01],
                  'reg_all': [0.2, 0.5]}

start = time.time()

svdpp_gs = GridSearchCV(SVD, svd_param_grid, measures=['rmse', 'mae'], cv=5, n_jobs=-1, joblib_verbose=2)
svdpp_gs.fit(data)

end = time.time()
print('svdpp_gs took {:.2f} seconds'.format(end-start))
notify("Notification", "Model is complete")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 12.5min
# svdpp_gs took 2920.02 seconds
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed: 48.3min finished

# %%
print('SVDpp - RMSE:', round(svdpp_gs.best_score['rmse'], 4), '- MAE:', round(svdpp_gs.best_score['mae'], 4))
# Out:
# SVDpp - RMSE: 1.1775 - MAE: 0.9439

# %%
svd_param_grid = {'n_epochs': [5, 10], 
                  'lr_all': [0.007, 0.009, 0.01],
                  'reg_all': [0.2, 0.5]}

start = time.time()

svd_gs = GridSearchCV(SVD, svd_param_grid, measures=['rmse', 'mae'], cv=5, n_jobs=-1, joblib_verbose=2)
svd_gs.fit(data)

end = time.time()
print('svd_gs took {:.2f} seconds'.format(end-start))
notify("Notification", "Model is complete")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 12.5min
# svd_gs took 1830.10 seconds
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed: 30.1min finished

# %%
print('SVD   - RMSE:', round(svd_gs.best_score['rmse'], 4), '- MAE:', round(svd_gs.best_score['mae'], 4))
# Out:
# SVD   - RMSE: 1.1776 - MAE: 0.944

# %%
x = svdpp_gs.cv_results['params']
y1 = svdpp_gs.cv_results['mean_test_rmse']
y2 = svdpp_gs.cv_results['mean_test_mae']

y3 = svd_gs.cv_results['mean_test_rmse']
y4 = svd_gs.cv_results['mean_test_mae']

# %%
x = [str(x1) for x1 in x]
x
# Out:
# ["{'n_epochs': 5, 'lr_all': 0.007, 'reg_all': 0.2}",
#  "{'n_epochs': 5, 'lr_all': 0.007, 'reg_all': 0.5}",
#  "{'n_epochs': 5, 'lr_all': 0.009, 'reg_all': 0.2}",
#  "{'n_epochs': 5, 'lr_all': 0.009, 'reg_all': 0.5}",
#  "{'n_epochs': 5, 'lr_all': 0.01, 'reg_all': 0.2}",
#  "{'n_epochs': 5, 'lr_all': 0.01, 'reg_all': 0.5}",
#  "{'n_epochs': 10, 'lr_all': 0.007, 'reg_all': 0.2}",
#  "{'n_epochs': 10, 'lr_all': 0.007, 'reg_all': 0.5}",
#  "{'n_epochs': 10, 'lr_all': 0.009, 'reg_all': 0.2}",
#  "{'n_epochs': 10, 'lr_all': 0.009, 'reg_all': 0.5}",
#  "{'n_epochs': 10, 'lr_all': 0.01, 'reg_all': 0.2}",
#  "{'n_epochs': 10, 'lr_all': 0.01, 'reg_all': 0.5}"]

# %% [markdown]
# ### Graphing the GridSearchCV results

# %%
index = [1, 3, 5, 7, 9, 11, 0, 2, 4, 6, 8, 10]

xx = []
yy = []
for i, j in enumerate(x):
    xx = xx+[x[index[i]]]
    yy = yy+[y1[index[i]]]

fig, ax = plt.subplots(2,1, figsize=(10,6))
ax[0].set_title('SVDpp on scores', loc='center', fontsize=15)
ax[0].plot([str(x1) for x1 in xx], yy, label='RMSE', color='darkgreen', marker='o')
ax[0].set_xticklabels(['','','','','',''])
# ax[0].barh([str(x1) for x1 in x], y1)
# ax[0].set_xlabel('Algorithms', fontsize=15)
ax[0].set_ylabel('RMSE Value', fontsize=15)
ax[0].legend()
ax[0].grid(ls='dashed')

# ax[1].set_title('SVDpp on MAE', loc='center', fontsize=15)
ax[1].plot([str(x1) for x1 in xx], y2, label='MAE', color='navy', marker='o')
ax[1].set_xticklabels([str(x1) for x1 in x], rotation=90)
ax[1].set_xlabel('Algorithms', fontsize=15)
ax[1].set_ylabel('MAE Value', fontsize=15)
ax[1].legend()
ax[1].grid(ls='dashed')

plt.savefig('../img/SVDpp_scores.png', dpi=300, transparency=True)
plt.show();

# %%
y1
# Out:
# array([1.19469029, 1.20215595, 1.18941691, 1.19717721, 1.18749122,
#        1.19534671, 1.18146586, 1.19002352, 1.178444  , 1.18698353,
#        1.17747944, 1.18602452])

# %%
fig, ax = plt.subplots(2,1, figsize=(10,6))
ax[0].set_title('SVDpp on scores', loc='center', fontsize=15)
ax[0].plot([str(x1) for x1 in x], y1, label='RMSE', color='darkgreen', marker='o')
ax[0].set_xticklabels(['','','','','',''])
# ax[0].barh([str(x1) for x1 in x], y1)
# ax[0].set_xlabel('Algorithms', fontsize=15)
ax[0].set_ylabel('RMSE Value', fontsize=15)
ax[0].legend()
ax[0].grid(ls='dashed')

# ax[1].set_title('SVDpp on MAE', loc='center', fontsize=15)
ax[1].plot([str(x1) for x1 in x], y2, label='MAE', color='navy', marker='o')
ax[1].set_xticklabels([str(x1) for x1 in x], rotation=90)
ax[1].set_xlabel('Algorithms', fontsize=15)
ax[1].set_ylabel('MAE Value', fontsize=15)
ax[1].legend()
ax[1].grid(ls='dashed')

plt.savefig('../img/SVDpp_scores.png', dpi=300, transparency=True)
plt.show();

# %%
fig, ax = plt.subplots(2,1, figsize=(10,6))
ax[0].set_title('SVD on scores', loc='center', fontsize=15)
ax[0].plot([str(x1) for x1 in x], y3, label='RMSE', color='darkgreen', marker='o')
ax[0].set_xticklabels(['','','','','',''])
# ax[0].barh([str(x1) for x1 in x], y1)
# ax[0].set_xlabel('Algorithms', fontsize=15)
ax[0].set_ylabel('RMSE Value', fontsize=15)
ax[0].legend()
ax[0].grid(ls='dashed')

# ax[1].set_title('SVDpp on MAE', loc='center', fontsize=15)
ax[1].plot([str(x1) for x1 in x], y4, label='MAE', color='navy', marker='o')
ax[1].set_xticklabels([str(x1) for x1 in x], rotation=90)
ax[1].set_xlabel('Algorithms', fontsize=15)
ax[1].set_ylabel('MAE Value', fontsize=15)
ax[1].legend()
ax[1].grid(ls='dashed')

plt.savefig('../img/SVD_scores.png', dpi=300, transparency=True)
plt.show();

# %% [markdown]
# ## Best model = SVD++
# * SVD++ (SVDpp) was marginally better than SVD in terms of RSME score (1.1775 vs 1.1776)
# * SVD++ also took 50% longer to compute over SVD (45min vs 30min)
# * SVD++ was also the best model from the <a href='http://buzzard.ups.edu/courses/2014spring/420projects/math420-UPS-spring-2014-gower-netflix-SVD.pdf'>$1M netflix competition</a> so it makes sense that it would work well in general
#
# #### Final Hyperparameters
# * epoch 10
# * learning rate 0.01
# * reg_all: 0.2

# %% [markdown]
# ## Testing Predictions using SVD++
#
# on trainset/testset

# %%
start = time.time()

algo=SVDpp(n_epochs=10, lr_all=0.01, reg_all=0.2, random_state=0, verbose=True)
algo.fit(trainset)

end = time.time()
print('this process took {:.2f} seconds'.format(end-start))
# Out:
#  processing epoch 0
#  processing epoch 1
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 5
#  processing epoch 6
#  processing epoch 7
#  processing epoch 8
#  processing epoch 9
# this process took 416.59 seconds

# %%
predictions = algo.test(testset)
accuracy.rmse(predictions)
# Out:
# RMSE: 1.1798
# 1.1798422331791565

# %%
uid = 0
iid = 4
algo.predict(uid, iid)
# Out:
# Prediction(uid=0, iid=4, r_ui=None, est=3.6549299517898515, details={'was_impossible': False})

# %% [markdown]
# ### First ten predictions

# %%
predictions[:10]
# Out:
# [Prediction(uid=20662, iid=3130, r_ui=4.0, est=4.055087464396904, details={'was_impossible': False}),
#  Prediction(uid=43414, iid=7985, r_ui=4.0, est=2.9781895575634163, details={'was_impossible': False}),
#  Prediction(uid=174275, iid=4419, r_ui=5.0, est=3.9836664388041534, details={'was_impossible': False}),
#  Prediction(uid=187680, iid=9265, r_ui=5.0, est=3.9158135809179297, details={'was_impossible': False}),
#  Prediction(uid=1062, iid=9380, r_ui=4.0, est=4.294048462289611, details={'was_impossible': False}),
#  Prediction(uid=9807, iid=5042, r_ui=2.0, est=3.4248082127449866, details={'was_impossible': False}),
#  Prediction(uid=52831, iid=559, r_ui=1.0, est=3.778683791648992, details={'was_impossible': False}),
#  Prediction(uid=1809, iid=23, r_ui=5.0, est=4.36463509056888, details={'was_impossible': False}),
#  Prediction(uid=3768, iid=3371, r_ui=2.0, est=3.9126327911530803, details={'was_impossible': False}),
#  Prediction(uid=2656, iid=1935, r_ui=3.0, est=2.7564351959437463, details={'was_impossible': False})]

# %%
AZNV_df.head()
# Out:
#               business_id                            name_x  \
# 0  vx4YAA02Qz6khRD1fZ1MFA                    Ping Pang Pong
# 1  glTBzDHv9wNhEsZa4bQrOA       CatHouse Boutique Nightclub
# 2  8Q6jl7OW8DZzwANggDspcw  Sugar Factory American Brasserie
# 3  41b2SLmjLcxTGLVRxASiDA                      Country Club
# 4  Ehy00JWQixgoXzisVKhvag           Cucina by Wolfgang Puck
#
#                                         address       city state postal_code  \
# 0                            4000 W Flamingo Rd  Las Vegas    NV       89103
# 1                         3900 Las Vegas Blvd S  Las Vegas    NV       89119
# 2  Paris Las Vegas Hotel, 3655 Las Vegas Blvd S  Las Vegas    NV       89109
# 3                         3131 Las Vegas Blvd S  Las Vegas    NV       89109
# 4                         3720 S Las Vegas Blvd  Las Vegas    NV       89158
#
#     latitude   longitude  stars_x  review_count_x  is_open  \
# 0  36.116901 -115.193512      3.5            1005        1
# 1  36.094822 -115.173216      3.0             178        0
# 2  36.112015 -115.172532      3.0             745        0
# 3  36.126720 -115.163553      4.0             269        0
# 4  36.107677 -115.175062      4.0             921        1
#
#                                           attributes  \
# 0  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 1  {'OutdoorSeating': 'False', 'BusinessAcceptsCr...
# 2  {'RestaurantsDelivery': 'False', 'RestaurantsA...
# 3  {'RestaurantsAttire': 'u'dressy'', 'Restaurant...
# 4  {'RestaurantsDelivery': 'False', 'RestaurantsP...
#
#                                           categories  \
# 0  [Cantonese, Seafood, Dim Sum, Restaurants, Chi...
# 1  [Restaurants, Nightlife, Lounges, American (Ne...
# 2  [Brasseries, Bars, Breakfast & Brunch, Food, C...
# 3  [Restaurants, Breakfast & Brunch, Seafood, Ame...
# 4                      [Restaurants, Italian, Pizza]
#
#                                                hours               review_id  \
# 0  {'Monday': '10:0-3:0', 'Tuesday': '10:0-3:0', ...  FwiJ7DQ3a9cBwp1OYlP5VA
# 1  {'Monday': '17:0-4:0', 'Tuesday': '17:0-4:0', ...  7ynnTyXiuIWHDkktHsdm4Q
# 2  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...  lO_55KRKtw2Rv1ZIHflX2w
# 3  {'Monday': '0:0-0:0', 'Tuesday': '11:30-14:30'...  0WHDB3dNcUsybN4zRJbFzw
# 4  {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...  tL3FZuCRK4q4d_bAF-VDOQ
#
#                   user_id  stars_y  useful  funny  cool  \
# 0  A0kENtCCoVT3m7T35zb2Vg      2.0       0      0     0
# 1  A0kENtCCoVT3m7T35zb2Vg      2.0       1      1     0
# 2  A0kENtCCoVT3m7T35zb2Vg      1.0       0      0     0
# 3  A0kENtCCoVT3m7T35zb2Vg      4.0       0      0     0
# 4  A0kENtCCoVT3m7T35zb2Vg      5.0       0      0     0
#
#                                                 text                 date  \
# 0  There are so many good reviews of this place o...  2010-04-02 20:37:54
# 1  Restaurant-only review; based on that, they wo...  2009-02-16 14:53:11
# 2  Are you allowed to post the phrase "sh*t show"...  2012-04-26 01:23:24
# 3  Our party of six enjoyed the Sunday jazz brunc...  2011-04-27 00:35:55
# 4  This was the best surprise of our recent trip ...  2012-04-26 01:11:46
#
#       name_y  review_count_y        yelping_since  \
# 0  Anastasia             348  2009-02-15 16:45:34
# 1  Anastasia             348  2009-02-15 16:45:34
# 2  Anastasia             348  2009-02-15 16:45:34
# 3  Anastasia             348  2009-02-15 16:45:34
# 4  Anastasia             348  2009-02-15 16:45:34
#
#                                              friends  fans  average_stars  \
# 0  BBY1Alonk5V0OLgk_G0rNQ, TY7QgNKJEhvo1zCULlT9Rg...     9           3.66
# 1  BBY1Alonk5V0OLgk_G0rNQ, TY7QgNKJEhvo1zCULlT9Rg...     9           3.66
# 2  BBY1Alonk5V0OLgk_G0rNQ, TY7QgNKJEhvo1zCULlT9Rg...     9           3.66
# 3  BBY1Alonk5V0OLgk_G0rNQ, TY7QgNKJEhvo1zCULlT9Rg...     9           3.66
# 4  BBY1Alonk5V0OLgk_G0rNQ, TY7QgNKJEhvo1zCULlT9Rg...     9           3.66
#
#    likes  compliments  elite_years  hotel?  userid  businessid
# 0    619           38            3       0       0           0
# 1    619           38            3       0       0           1
# 2    619           38            3       0       0           2
# 3    619           38            3       0       0           3
# 4    619           38            3       0       0           4

# %%
summary_df = AZNV_df.groupby(['state', 'city', 'name_x', 'business_id', 'stars_x'])['review_id'].count().sort_values(axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last').to_frame()
summary_df = summary_df.reset_index()
summary_df.head(10)
# Out:
#   state       city                  name_x             business_id  stars_x  \
# 0    NV  Las Vegas            Mon Ami Gabi  4JNXUYY8wbaaDmk3BPzlWw      4.0
# 1    NV  Las Vegas        Bacchanal Buffet  RESDUcs7fIiihp38-d6_6g      4.0
# 2    NV  Las Vegas            Wicked Spoon  K7lWdNUhCbcnEvI0NhGewg      3.5
# 3    NV  Las Vegas        Earl of Sandwich  DkYS3arLOhA8si5uUEmHOw      4.5
# 4    NV  Las Vegas      Hash House A Go Go  f4x1YBxkLrZg652xt2KR5g      4.0
# 5    NV  Las Vegas     Gordon Ramsay BurGR  cYwJA2A6I12KNkm2rtXd5g      4.0
# 6    NV  Las Vegas            Secret Pizza  iCQpiavjjPzJ5_3gPD5Ebg      4.0
# 7    NV  Las Vegas           Lotus of Siam  KskYqH1Bi7Z_61pH6Om8pg      4.0
# 8    NV  Las Vegas  The Buffet at Bellagio  ujHiaprwCQ5ewziu0Vi9rw      3.5
# 9    NV  Las Vegas           Serendipity 3  eoHdUeQDNgQ6WYEnP2aiRw      3.0
#
#    review_id
# 0       5362
# 1       5162
# 2       4371
# 3       3735
# 4       3330
# 5       3159
# 6       3076
# 7       2771
# 8       2762
# 9       2696

# %%
city_df = summary_df.groupby(['state', 'city'])['review_id'].sum().sort_values(axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last').to_frame()
city_df = city_df.reset_index()
city_df.head(10)
# Out:
#   state        city  review_id
# 0    NV   Las Vegas     807921
# 1    AZ     Phoenix     324853
# 2    AZ  Scottsdale     172281
# 3    AZ       Tempe      89927
# 4    NV   Henderson      85176
# 5    AZ    Chandler      68830
# 6    AZ        Mesa      66943
# 7    AZ     Gilbert      53971
# 8    AZ    Glendale      42317
# 9    AZ      Peoria      22914

# %% [markdown]
# # Scoring the Predictions
#
# Finding the Hit-Rate or Accuracy, how many times did we correctly predict the rating of the user?
#
# https://towardsdatascience.com/evaluating-a-real-life-recommender-system-error-based-and-ranking-based-84708e3285b

# %%
start = time.time()

score_df = AZNV_df[['business_id', 'name_x', 'city', 'state', 'stars_x', 'stars_y', 'date']]

# user_labels and businesslabels are from code in the beginning to create the df for spark ALS
# user_labels, user_uniques = pd.factorize(AZNV_df['user_id'])
# business_labels, business_uniques = pd.factorize(AZNV_df['business_id'])
score_df['userid'] = user_labels
score_df['restaurantid'] = business_labels
score_df['pred_rating'] = score_df.apply(lambda x: algo.predict(x.userid, x.restaurantid)[3], axis=1)

end = time.time()
os.system('say "the scoring has finished"');

print(score_df.shape)
score_df.head()
# Out:
# 0
# (1818490, 10)
#               business_id                            name_x       city state  \
# 0  vx4YAA02Qz6khRD1fZ1MFA                    Ping Pang Pong  Las Vegas    NV
# 1  glTBzDHv9wNhEsZa4bQrOA       CatHouse Boutique Nightclub  Las Vegas    NV
# 2  8Q6jl7OW8DZzwANggDspcw  Sugar Factory American Brasserie  Las Vegas    NV
# 3  41b2SLmjLcxTGLVRxASiDA                      Country Club  Las Vegas    NV
# 4  Ehy00JWQixgoXzisVKhvag           Cucina by Wolfgang Puck  Las Vegas    NV
#
#    stars_x  stars_y                 date  userid  restaurantid  pred_rating
# 0      3.5      2.0  2010-04-02 20:37:54       0             0     3.633105
# 1      3.0      2.0  2009-02-16 14:53:11       0             1     3.502029
# 2      3.0      1.0  2012-04-26 01:23:24       0             2     3.038446
# 3      4.0      4.0  2011-04-27 00:35:55       0             3     3.963400
# 4      4.0      5.0  2012-04-26 01:11:46       0             4     3.909215

# %%
score_df['accuracy'] = score_df.apply(lambda x: 1 if round(abs(x.stars_y-x.pred_rating))==0 else 0, axis=1)
print('the accuracy of the model pred: {:2f}'.format(sum(score_df.accuracy)/len(score_df)))
# Out:
# the accuracy of the model pred: 0.281565

# %% [markdown]
# ### My model had an accuracy of 28%, this better than random guessing of 1/5 or 20%
#
# ### How does it compare to guessing the mean or median?

# %%
np.mean(score_df.stars_y)
# Out:
# 3.789515477126627

# %%
score_df['mean_accuracy'] = score_df.apply(lambda x: 1 if round(abs(3.789515477126627-x.pred_rating))==0 else 0, axis=1)
print('evaluating prediction ratings against the mean of actual ratings: {:2f}'.format(sum(score_df.mean_accuracy)/len(score_df)))
# Out:
# evaluating prediction ratings against the mean of actual ratings: 0.806832

# %%
np.median(score_df.stars_y)
# Out:
# 4.0

# %%
score_df['median_accuracy'] = score_df.apply(lambda x: 1 if round(abs(4.0-x.pred_rating))==0 else 0, axis=1)
print('evaluating prediction ratings against the mean of actual ratings: {:2f}'.format(sum(score_df.median_accuracy)/len(score_df)))
# Out:
# evaluating prediction ratings against the mean of actual ratings: 0.789338

# %% [markdown]
# ### Guessing the mean or median turns out to be more accurate.
# * Mean - 80.68% accuracy
# * Median - 78.93% accuracy
#
# ### Let's see how far off our predictions are from by 0.5 and 1 star from the actual
#
# The idea behind this is many reviews may want to rate a place 3.5 stars but may end up rating a 3.0 or 4.0 since the Yelp dataset only allow ratings in whole numbers.
#
# Another concept is that one reviewer may rate a place 3 stars one-day and 4 stars the next, so there may also some qualitative fluxuations in accessing a restaurant

# %%
score_df['accuracy_by_half_star'] = score_df.apply(lambda x: 1 if abs(x.stars_y-x.pred_rating)<=0.5 else 0, axis=1)
print('accuracy +/-0.5 stars of model pred: {:2f}'.format(sum(score_df.accuracy_by_half_star)/len(score_df)))
# Out:
# accuracy +/-0.5 stars of model pred: 0.281565

# %% [markdown]
# ### cannot round by half-stars easily, let's look at whole stars

# %%
score_df['accuracy_by_one_star'] = score_df.apply(lambda x: 1 if round(abs(x.stars_y-x.pred_rating))<=1 else 0, axis=1)
print('accuracy +/-1 stars of model pred: {:2f}'.format(sum(score_df.accuracy_by_one_star)/len(score_df)))
# Out:
# accuracy +/-1 stars of model pred: 0.816542

# %% [markdown]
# ### Model Accuracy:
#
# Exact Match    :  <b>28.16%</b>
# <br>
# Match by 1-star:  <b>81.65%</b>

# %% [markdown]
# # Recommendations
#
# This part is tied to the development of a web demo

# %% [markdown]
# ## Prediction
#
# ### Creating Recommendation for new users (cold start)
#
# * have new user input 5-star ratings into the recommender
# * recommender will provide top results by city, cuisine similiarity, etc
#
# Find predictions for a user
#
# * step 1: input: 5 ratings from new user
# * step 2: retrain model
# * step 3: output: provide recommendations

# %% [markdown]
# ### First, need to create dataframes for performing predictions

# %%
# this is the dataframe for the predictive model

print(pandas_df.shape)
pandas_df.head()
# Out:
# (1818490, 3)
#    userid  restaurantid  rating
# 0       0             0     2.0
# 1       0             1     2.0
# 2       0             2     1.0
# 3       0             3     4.0
# 4       0             4     5.0

# %%
# dataframe to look up business name from once we have the predicted restaurant recommendation

ref_df = AZNV_df[['business_id', 'name_x', 'stars_x', 'review_count_x', 'city', 'state']]
# ref_df['p_userid'] = pandas_df['userid'] 
ref_df['p_restaurantid'] = pandas_df['restaurantid']
# ref_df['p_rating'] = pandas_df['rating']
ref_df = ref_df.drop_duplicates()
print(ref_df.shape)
ref_df.head()
# Out:
# (14797, 7)
#               business_id                            name_x  stars_x  \
# 0  vx4YAA02Qz6khRD1fZ1MFA                    Ping Pang Pong      3.5
# 1  glTBzDHv9wNhEsZa4bQrOA       CatHouse Boutique Nightclub      3.0
# 2  8Q6jl7OW8DZzwANggDspcw  Sugar Factory American Brasserie      3.0
# 3  41b2SLmjLcxTGLVRxASiDA                      Country Club      4.0
# 4  Ehy00JWQixgoXzisVKhvag           Cucina by Wolfgang Puck      4.0
#
#    review_count_x       city state  p_restaurantid
# 0            1005  Las Vegas    NV               0
# 1             178  Las Vegas    NV               1
# 2             745  Las Vegas    NV               2
# 3             269  Las Vegas    NV               3
# 4             921  Las Vegas    NV               4

# %% [markdown]
# ### Pickle the dfs

# %%
ref_df.to_pickle('../data/ref_df.p')

# %% [markdown]
# ### Code to load dataframes faster when booting up next

# %%
pandas_df = pd.read_pickle('../data/model_pandas_df.p')
ref_df = pd.read_pickle('../data/ref_df.p')
print('ref_df: ', ref_df.shape)
print('pandas_df: ', pandas_df.shape)
# Out:
# ref_df:  (14797, 7)
# pandas_df:  (1818490, 3)

# %% [markdown]
# ### Get list of restaurants for user to choose from
#
# Filtered for restaurants in Las Vegas, NV with overall review > 4.0

# %%
r_df = ref_df[ref_df['city']=='Las Vegas']
r_df = r_df[r_df['state']=='NV']
r_df = r_df[r_df['stars_x']>=4.0]
r_df = r_df.sort_values(by=['review_count_x'], ascending=False)
r_df.head()
# Out:
#                business_id               name_x  stars_x  review_count_x  \
# 67  4JNXUYY8wbaaDmk3BPzlWw         Mon Ami Gabi      4.0            8348
# 70  RESDUcs7fIiihp38-d6_6g     Bacchanal Buffet      4.0            8339
# 34  f4x1YBxkLrZg652xt2KR5g   Hash House A Go Go      4.0            5763
# 17  cYwJA2A6I12KNkm2rtXd5g  Gordon Ramsay BurGR      4.0            5484
# 23  DkYS3arLOhA8si5uUEmHOw     Earl of Sandwich      4.5            5075
#
#          city state  p_restaurantid
# 67  Las Vegas    NV              61
# 70  Las Vegas    NV              64
# 34  Las Vegas    NV              34
# 17  Las Vegas    NV              17
# 23  Las Vegas    NV              23

# %%
rid_list = list(r_df.head(12)['p_restaurantid'])
rid_list
# Out:
# [61, 64, 34, 17, 23, 86, 29, 87, 767, 4178, 1524, 45]

# %%
rname_list = list(r_df.head(12)['name_x'])
rname_list
# Out:
# ['Mon Ami Gabi',
#  'Bacchanal Buffet',
#  'Hash House A Go Go',
#  'Gordon Ramsay BurGR',
#  'Earl of Sandwich',
#  'Secret Pizza',
#  'Lotus of Siam',
#  'Bouchon',
#  'Yardbird Southern Table & Bar',
#  'Gordon Ramsay Steak',
#  'Gangnam Asian BBQ Dining',
#  'Bachi Burger']

# %% [markdown]
# ### Enter every permutation of the new users ratings into the dataframe
#
# * this will allow us to provide score predictions on any restaurant in the model
#
# * Then evalulate what is the best restaurant to recommend

# %% [markdown]
# #### making a list of lists of all of the possibilities

# %%
# there are 12 restaraunts choose 5, 792 combinations

# from https://www.geeksforgeeks.org/permutation-and-combination-in-python/
# A Python program to print all combinations of given length 
from itertools import combinations 

# Get all combinations of [1, 2, 3] and length 2 
comb = list(combinations(rid_list, 5)) #comb is the list of all combinations (12 choose 5)

# Print the obtained combinations 
# for i in list(comb): 
#     print (i) 

print(comb[:5])
len(comb)
# Out:
# [(61, 64, 34, 17, 23), (61, 64, 34, 17, 86), (61, 64, 34, 17, 29), (61, 64, 34, 17, 87), (61, 64, 34, 17, 767)]
# 792

# %%
# function to add user prediction

def add_user_rating(df, userid, restaurant_list, rating_list):
    for i, restaurant in enumerate(restaurant_list):
        df = df.append({'userid':userid, 'restaurantid':restaurant, 'rating':rating_list[i]}, ignore_index=True)
    return df

# %%
uid_count=300000 #userid counter, all inputted users with will a userid > 300000
rating_lst = [5, 5, 5, 5, 5] #every picked restaurant gets a 5.

test_df = pandas_df.copy()
for r_list in comb:
    uid_count+=1
    test_df = add_user_rating(test_df, uid_count, list(r_list), rating_lst)

print(test_df.shape)
test_df.tail(10)
# Out:
# (1822450, 3)
#          userid  restaurantid  rating
# 1822440  300791            29     5.0
# 1822441  300791           767     5.0
# 1822442  300791          4178     5.0
# 1822443  300791          1524     5.0
# 1822444  300791            45     5.0
# 1822445  300792            87     5.0
# 1822446  300792           767     5.0
# 1822447  300792          4178     5.0
# 1822448  300792          1524     5.0
# 1822449  300792            45     5.0

# %% [markdown]
# ### Train the model with the new user's ratings

# %%
# Set Rating Scale
reader = Reader(rating_scale=(1, 5))

# Load data with rating scale
data = Dataset.load_from_df(test_df, reader)

# train on full dataset
# https://surprise.readthedocs.io/en/stable/getting_started.html
trainset = data.build_full_trainset()

start = time.time()

algo=SVDpp(n_epochs=10, lr_all=0.01, reg_all=0.2, random_state=0, verbose=False)
algo.fit(trainset)

end = time.time()
print('this process took {:.2f} seconds'.format(end-start))

os.system('say "the model has finished"');
# Out:
# this process took 731.66 seconds

# %%
uid=300001
iid=64
algo.predict(uid, iid)
# Out:
# Prediction(uid=300001, iid=64, r_ui=None, est=5, details={'was_impossible': False})

# %% [markdown]
# ## Building the Prediction DF

# %%
# algo.predict(uid, iid)

start = time.time()

restaurant_list = test_df['restaurantid'].unique()
pred_list = []

for uid in range(300001, 300792+1): #loop through every added user
    for iid in restaurant_list: #loop through every restaurant in our dataset
        pred_rating = algo.predict(uid, iid)[3]
        pred_list.append(pred_rating)

#method to duplicate lists by n times
def duplicate(testList, n):
    new_list = [] 
    for i in range(n):
        new_list.extend(testList)
    return new_list
        
# create list of userids to add to a prediction df
userid_list = [[i]*len(restaurant_list) for i in range(300001, 300792+1)]
userid_list = [item for sublist in userid_list for item in sublist]

# create list of restaurantid to add to a prediction df
restaurant_list = duplicate(restaurant_list, 792)

#create prediction DF
pred_df = pd.DataFrame()
pred_df['uid'] = userid_list
pred_df['restaurantid'] = restaurant_list
pred_df['pred_rating'] = pred_list

end = time.time()

print('this process took {:.2f} seconds'.format(end-start))
os.system('say "the prediction dataframe has finished compiling"');

print(pred_df.shape)
pred_df.head()
# Out:
# this process took 301.22 seconds
# 0
# (11719224, 3)
#       uid  restaurantid  pred_rating
# 0  300001             0     4.141554
# 1  300001             1     3.849536
# 2  300001             2     3.510306
# 3  300001             3     4.455940
# 4  300001             4     4.344842

# %% [markdown]
# ### Remove the 12 restaurants from the list of predictions

# %%
for rid in rid_list:
    pred_df = pred_df[pred_df['restaurantid']!=rid]

pred_df.shape
# Out:
# (11709720, 3)

# %% [markdown]
# ### Pickle this result

# %%
pred_df.to_pickle('../data/pred_df.p')

# %% [markdown]
# ### load pickle

# %%
pred_df = pd.read_pickle('../data/pred_df.p')

# %% [markdown]
# ## Get top 3 recommendation for each user (Vegas / Phoenix)

# %%
# sort df
pred_df = pred_df.sort_values(by=['pred_rating'], ascending=False)

# %%
pred_df2 = pd.merge(pred_df, ref_df, how='inner', left_on='restaurantid', right_on='p_restaurantid')

print(pred_df.shape)
pred_df2.head()
# Out:
# (11709720, 3)
#       uid  restaurantid  pred_rating             business_id           name_x  \
# 0  300199         11103          5.0  VEknvhHwiTTSCR1ALRN0GA  Grocery Station
# 1  300098         11103          5.0  VEknvhHwiTTSCR1ALRN0GA  Grocery Station
# 2  300097         11103          5.0  VEknvhHwiTTSCR1ALRN0GA  Grocery Station
# 3  300142         11103          5.0  VEknvhHwiTTSCR1ALRN0GA  Grocery Station
# 4  300061         11103          5.0  VEknvhHwiTTSCR1ALRN0GA  Grocery Station
#
#    stars_x  review_count_x        city state  p_restaurantid
# 0      5.0              42  Scottsdale    AZ           11103
# 1      5.0              42  Scottsdale    AZ           11103
# 2      5.0              42  Scottsdale    AZ           11103
# 3      5.0              42  Scottsdale    AZ           11103
# 4      5.0              42  Scottsdale    AZ           11103

# %% [markdown]
# ### Removing Review count < 300
#
# want to recommend more established restaurants

# %%
pred_df2 = pred_df2[pred_df2['review_count_x']>300]
pred_df2.head(2)
# Out:
#           uid  restaurantid  pred_rating             business_id  \
# 15840  300013          7845          5.0  52yWGkwnrQXIjvuMjYxsiA
# 15841  300017          7845          5.0  52yWGkwnrQXIjvuMjYxsiA
#
#                       name_x  stars_x  review_count_x     city state  \
# 15840  Not Your Typical Deli      5.0             402  Gilbert    AZ
# 15841  Not Your Typical Deli      5.0             402  Gilbert    AZ
#
#        p_restaurantid
# 15840            7845
# 15841            7845

# %% [markdown]
# ### Arizona DF
#
# returns a dataframe with the top 5 recommendations for each user in Phoenix

# %%
start = time.time()

az_pred_df = pred_df2[pred_df2['state']=='AZ']
az_pred_df = az_pred_df[az_pred_df['city']=='Phoenix']

top_phoenix_pred_df = pd.DataFrame()

for uid in range(300001, 300792+1):
    temp_df = az_pred_df[az_pred_df['uid']==uid].head(5)
    top_phoenix_pred_df = top_phoenix_pred_df.append(temp_df, ignore_index=True)

end = time.time()

print('the process was complete in {:.2f} seconds'.format(end-start))
os.system('say "the dataframe is complete!!"');

print(top_phoenix_pred_df.shape)
top_phoenix_pred_df.head(10)
# Out:
# the process was complete in 3.87 seconds
# 0
# (3960, 10)
#       uid  restaurantid  pred_rating             business_id  \
# 0  300001          3041     4.935928  Cp-clhAJs3NJRwXpXk_saw
# 1  300001          3284     4.951550  Xg5qEQiB-7L6kGJ5F4K3bQ
# 2  300001          7584     4.943484  fSBhe0A6Dfa8JCYccfpMog
# 3  300001          2676     4.923398  jIzygnVmajEXYmfsBNY_Gw
# 4  300001          4921     4.911963  NeDqVEiin0q-FxCvOKiERw
# 5  300002          3041     4.977238  Cp-clhAJs3NJRwXpXk_saw
# 6  300002          3284     4.964212  Xg5qEQiB-7L6kGJ5F4K3bQ
# 7  300002          7584     4.951642  fSBhe0A6Dfa8JCYccfpMog
# 8  300002          2676     4.921192  jIzygnVmajEXYmfsBNY_Gw
# 9  300002          4921     4.908785  NeDqVEiin0q-FxCvOKiERw
#
#                          name_x  stars_x  review_count_x     city state  \
# 0       The Whining Pig-Phoenix      4.5             378  Phoenix    AZ
# 1               Little Miss BBQ      5.0            1936  Phoenix    AZ
# 2                 The Bagel Man      4.5             518  Phoenix    AZ
# 3         Most Wanted Taco Shop      4.5             576  Phoenix    AZ
# 4  My Slice of the Pie Pizzeria      4.5             318  Phoenix    AZ
# 5       The Whining Pig-Phoenix      4.5             378  Phoenix    AZ
# 6               Little Miss BBQ      5.0            1936  Phoenix    AZ
# 7                 The Bagel Man      4.5             518  Phoenix    AZ
# 8         Most Wanted Taco Shop      4.5             576  Phoenix    AZ
# 9  My Slice of the Pie Pizzeria      4.5             318  Phoenix    AZ
#
#    p_restaurantid
# 0            3041
# 1            3284
# 2            7584
# 3            2676
# 4            4921
# 5            3041
# 6            3284
# 7            7584
# 8            2676
# 9            4921

# %% [markdown]
# ### Vegas DF

# %%
start = time.time()

az_pred_df = pred_df2[pred_df2['state']=='NV']
az_pred_df = az_pred_df[az_pred_df['city']=='Las Vegas']

top_vegas_pred_df = pd.DataFrame()

for uid in range(300001, 300792+1):
    temp_df = az_pred_df[az_pred_df['uid']==uid].head(5)
    top_vegas_pred_df = top_vegas_pred_df.append(temp_df, ignore_index=True)

end = time.time()

print('the process was complete in {:.2f} seconds'.format(end-start))
os.system('say "the dataframe is complete!!"');

print(top_vegas_pred_df.shape)
top_vegas_pred_df.head(10)
# Out:
# the process was complete in 4.19 seconds
# 0
# (3960, 10)
#       uid  restaurantid  pred_rating             business_id  \
# 0  300001           168     5.000000  IhNASEZ3XnBHmuuVnWdIwA
# 1  300001          1054     5.000000  O7UMzd3i-Zk8dMeyY9ZwoA
# 2  300001          1580     5.000000  8fFTJBh0RB2EKG53ibiBKw
# 3  300001           106     4.989649  L1-1P3acJc4gEFvWwjXcNQ
# 4  300001           238     4.965342  wWuGa3OOQJro_XGe-GKBXA
# 5  300002           168     5.000000  IhNASEZ3XnBHmuuVnWdIwA
# 6  300002          1054     5.000000  O7UMzd3i-Zk8dMeyY9ZwoA
# 7  300002          1580     5.000000  8fFTJBh0RB2EKG53ibiBKw
# 8  300002           106     5.000000  L1-1P3acJc4gEFvWwjXcNQ
# 9  300002           238     4.995443  wWuGa3OOQJro_XGe-GKBXA
#
#                name_x  stars_x  review_count_x       city state  \
# 0        Brew Tea Bar      5.0            1506  Las Vegas    NV
# 1      Art of Flavors      5.0             350  Las Vegas    NV
# 2      Zenaida's Cafe      5.0             374  Las Vegas    NV
# 3  Meráki Greek Grill      4.5             553  Las Vegas    NV
# 4              Kabuto      4.5             601  Las Vegas    NV
# 5        Brew Tea Bar      5.0            1506  Las Vegas    NV
# 6      Art of Flavors      5.0             350  Las Vegas    NV
# 7      Zenaida's Cafe      5.0             374  Las Vegas    NV
# 8  Meráki Greek Grill      4.5             553  Las Vegas    NV
# 9              Kabuto      4.5             601  Las Vegas    NV
#
#    p_restaurantid
# 0             168
# 1            1054
# 2            1580
# 3             106
# 4             238
# 5             168
# 6            1054
# 7            1580
# 8             106
# 9             238

# %% [markdown]
# ## Let's recommend!!

# %%
## enumerate the rid_list and append those numbers to df, then we can look up the df index and provide best recommendation

# replace the ending of this url with the business_id to link to business = https://www.yelp.com/biz/IhNASEZ3XnBHmuuVnWdIwA

# %% [markdown]
# ## for website

# %%
# get 3 random profiles:

comb[100], comb[500], comb[601]
# Out:
# ((61, 64, 29, 87, 767), (64, 23, 87, 1524, 45), (34, 23, 86, 87, 767))

# %%
name=[]
for id in list(comb[100]):
    name.append(ref_df[ref_df['p_restaurantid']==id]['name_x'].to_string())
name
# Out:
# ['67    Mon Ami Gabi',
#  '70    Bacchanal Buffet',
#  '29    Lotus of Siam',
#  '97    Bouchon',
#  '1050    Yardbird Southern Table & Bar']

# %%
name=[]
for id in list(comb[500]):
    name.append(ref_df[ref_df['p_restaurantid']==id]['name_x'].to_string())
name
# Out:
# ['70    Bacchanal Buffet',
#  '23    Earl of Sandwich',
#  '97    Bouchon',
#  '2195    Gangnam Asian BBQ Dining',
#  '50    Bachi Burger']

# %%
name=[]
for id in list(comb[600]):
    name.append(ref_df[ref_df['p_restaurantid']==id]['name_x'].to_string())
name
# Out:
# ['34    Hash House A Go Go',
#  '23    Earl of Sandwich',
#  '95    Secret Pizza',
#  '29    Lotus of Siam',
#  '50    Bachi Burger']

# %%
comb[0] = 300601
# Out:
# (61, 64, 34, 17, 23)

# %%
top_phoenix_pred_df[top_phoenix_pred_df['uid']==300101]
# Out:
#         uid  restaurantid  pred_rating             business_id  \
# 500  300101          3041     4.829382  Cp-clhAJs3NJRwXpXk_saw
# 501  300101          3284     4.830601  Xg5qEQiB-7L6kGJ5F4K3bQ
# 502  300101          7584     4.812113  fSBhe0A6Dfa8JCYccfpMog
# 503  300101          2676     4.792500  jIzygnVmajEXYmfsBNY_Gw
# 504  300101          4921     4.773161  NeDqVEiin0q-FxCvOKiERw
#
#                            name_x  stars_x  review_count_x     city state  \
# 500       The Whining Pig-Phoenix      4.5             378  Phoenix    AZ
# 501               Little Miss BBQ      5.0            1936  Phoenix    AZ
# 502                 The Bagel Man      4.5             518  Phoenix    AZ
# 503         Most Wanted Taco Shop      4.5             576  Phoenix    AZ
# 504  My Slice of the Pie Pizzeria      4.5             318  Phoenix    AZ
#
#      p_restaurantid
# 500            3041
# 501            3284
# 502            7584
# 503            2676
# 504            4921

# %%
top_vegas_pred_df[top_vegas_pred_df['uid']==300101]
# Out:
#         uid  restaurantid  pred_rating             business_id  \
# 500  300101           168     4.968486  IhNASEZ3XnBHmuuVnWdIwA
# 501  300101          1054     4.889348  O7UMzd3i-Zk8dMeyY9ZwoA
# 502  300101          1580     4.895210  8fFTJBh0RB2EKG53ibiBKw
# 503  300101           106     4.868280  L1-1P3acJc4gEFvWwjXcNQ
# 504  300101           238     4.853156  wWuGa3OOQJro_XGe-GKBXA
#
#                  name_x  stars_x  review_count_x       city state  \
# 500        Brew Tea Bar      5.0            1506  Las Vegas    NV
# 501      Art of Flavors      5.0             350  Las Vegas    NV
# 502      Zenaida's Cafe      5.0             374  Las Vegas    NV
# 503  Meráki Greek Grill      4.5             553  Las Vegas    NV
# 504              Kabuto      4.5             601  Las Vegas    NV
#
#      p_restaurantid
# 500             168
# 501            1054
# 502            1580
# 503             106
# 504             238

# %%
top_phoenix_pred_df[top_phoenix_pred_df['uid']==300501]
# Out:
#          uid  restaurantid  pred_rating             business_id  \
# 2500  300501          3041     4.712992  Cp-clhAJs3NJRwXpXk_saw
# 2501  300501          3284     4.718811  Xg5qEQiB-7L6kGJ5F4K3bQ
# 2502  300501          7584     4.688768  fSBhe0A6Dfa8JCYccfpMog
# 2503  300501          2676     4.668690  jIzygnVmajEXYmfsBNY_Gw
# 2504  300501          4921     4.670364  NeDqVEiin0q-FxCvOKiERw
#
#                             name_x  stars_x  review_count_x     city state  \
# 2500       The Whining Pig-Phoenix      4.5             378  Phoenix    AZ
# 2501               Little Miss BBQ      5.0            1936  Phoenix    AZ
# 2502                 The Bagel Man      4.5             518  Phoenix    AZ
# 2503         Most Wanted Taco Shop      4.5             576  Phoenix    AZ
# 2504  My Slice of the Pie Pizzeria      4.5             318  Phoenix    AZ
#
#       p_restaurantid
# 2500            3041
# 2501            3284
# 2502            7584
# 2503            2676
# 2504            4921

# %%
top_vegas_pred_df[top_vegas_pred_df['uid']==300501]
# Out:
#          uid  restaurantid  pred_rating             business_id  \
# 2500  300501           168     4.849986  IhNASEZ3XnBHmuuVnWdIwA
# 2501  300501          1054     4.764936  O7UMzd3i-Zk8dMeyY9ZwoA
# 2502  300501          1580     4.784205  8fFTJBh0RB2EKG53ibiBKw
# 2503  300501           106     4.747462  L1-1P3acJc4gEFvWwjXcNQ
# 2504  300501           238     4.730348  wWuGa3OOQJro_XGe-GKBXA
#
#                   name_x  stars_x  review_count_x       city state  \
# 2500        Brew Tea Bar      5.0            1506  Las Vegas    NV
# 2501      Art of Flavors      5.0             350  Las Vegas    NV
# 2502      Zenaida's Cafe      5.0             374  Las Vegas    NV
# 2503  Meráki Greek Grill      4.5             553  Las Vegas    NV
# 2504              Kabuto      4.5             601  Las Vegas    NV
#
#       p_restaurantid
# 2500             168
# 2501            1054
# 2502            1580
# 2503             106
# 2504             238

# %%
top_phoenix_pred_df[top_phoenix_pred_df['uid']==300601]
# Out:
#          uid  restaurantid  pred_rating             business_id  \
# 3000  300601          3041     4.693274  Cp-clhAJs3NJRwXpXk_saw
# 3001  300601          3284     4.714452  Xg5qEQiB-7L6kGJ5F4K3bQ
# 3002  300601          7584     4.684041  fSBhe0A6Dfa8JCYccfpMog
# 3003  300601          2676     4.664611  jIzygnVmajEXYmfsBNY_Gw
# 3004  300601          4921     4.649343  NeDqVEiin0q-FxCvOKiERw
#
#                             name_x  stars_x  review_count_x     city state  \
# 3000       The Whining Pig-Phoenix      4.5             378  Phoenix    AZ
# 3001               Little Miss BBQ      5.0            1936  Phoenix    AZ
# 3002                 The Bagel Man      4.5             518  Phoenix    AZ
# 3003         Most Wanted Taco Shop      4.5             576  Phoenix    AZ
# 3004  My Slice of the Pie Pizzeria      4.5             318  Phoenix    AZ
#
#       p_restaurantid
# 3000            3041
# 3001            3284
# 3002            7584
# 3003            2676
# 3004            4921

# %%
top_vegas_pred_df[top_vegas_pred_df['uid']==300601]
# Out:
#          uid  restaurantid  pred_rating             business_id  \
# 3000  300601           168     4.836931  IhNASEZ3XnBHmuuVnWdIwA
# 3001  300601          1054     4.763186  O7UMzd3i-Zk8dMeyY9ZwoA
# 3002  300601          1580     4.786490  8fFTJBh0RB2EKG53ibiBKw
# 3003  300601           106     4.724365  L1-1P3acJc4gEFvWwjXcNQ
# 3004  300601           238     4.717987  wWuGa3OOQJro_XGe-GKBXA
#
#                   name_x  stars_x  review_count_x       city state  \
# 3000        Brew Tea Bar      5.0            1506  Las Vegas    NV
# 3001      Art of Flavors      5.0             350  Las Vegas    NV
# 3002      Zenaida's Cafe      5.0             374  Las Vegas    NV
# 3003  Meráki Greek Grill      4.5             553  Las Vegas    NV
# 3004              Kabuto      4.5             601  Las Vegas    NV
#
#       p_restaurantid
# 3000             168
# 3001            1054
# 3002            1580
# 3003             106
# 3004             238

# %%
r_df.head(100)
# Out:
#                   business_id                                       name_x  \
# 67     4JNXUYY8wbaaDmk3BPzlWw                                 Mon Ami Gabi
# 70     RESDUcs7fIiihp38-d6_6g                             Bacchanal Buffet
# 34     f4x1YBxkLrZg652xt2KR5g                           Hash House A Go Go
# 17     cYwJA2A6I12KNkm2rtXd5g                          Gordon Ramsay BurGR
# 23     DkYS3arLOhA8si5uUEmHOw                             Earl of Sandwich
# 95     iCQpiavjjPzJ5_3gPD5Ebg                                 Secret Pizza
# 29     KskYqH1Bi7Z_61pH6Om8pg                                Lotus of Siam
# 97     rcaPajgKOJC2vo_l3xa42A                                      Bouchon
# 1050   faPVqws-x-5k2CQKDNtHxw                Yardbird Southern Table & Bar
# 10626  OETh78qcgDltvHULowwhJg                          Gordon Ramsay Steak
# 2195   hihud--QRriCYZw1zZvW4g                     Gangnam Asian BBQ Dining
# 50     7sPNbCx7vGAaH7SbNPZ6oA                                 Bachi Burger
# 1359   3kdSl5mo9dWC4clrQjEDGg                                      Egg & I
# 1291   g8OnV26ywJlZpezdBnOWUQ                           Hash House A Go Go
# 1923   XZbuPXdyA0ZtTu3AzqtQhg                                   Mesa Grill
# 43     XXW_OFaYQkkGOGniujZFHg  The Peppermill Restaurant & Fireside Lounge
# 124    RwMLuOkImBIqqYj4SSKSPg                               Tacos El Gordo
# 284    P7pxQFqr7yBKMMI2J51udw                                    Holsteins
# 1386   fL-b760btOaGa85OJ9ut3w                        Rollin Smoke Barbeque
# 31     QJatAcxYgK1Zp9BRZMAx7g                                  Shake Shack
# 177    NvKNe9DnQavC9GstglcBJQ                               Grand Lux Cafe
# 1787   JDZ6_yycNQFTpUZzLIKHUg                            El Dorado Cantina
# 25     UPIYuRaZvknINOd1w8kqRQ                                  Monta Ramen
# 1809   Cni2l-VKG_pdospJ6xliXQ                                   Burger Bar
# 3674   mDR12Hafvr84ctpsV6YLag                                     Mr Mamas
# 3622   igHYkXZMLAc9UdV5VnR_AA                                   Echo & Rig
# 47     awI4hHMfa7H0Xf0-ChU5hg                               The Oyster Bar
# 12     I6EDDi4-Eq_XlFghcDCUhw        Joes Seafood Prime Steak & Stone Crab
# 8400   QXV3L_QFGj8r6nWX2kS2hA                                  Nacho Daddy
# 134    pH0BLkL4cbxKzu471VZnuA                       SUSHISAMBA - Las Vegas
# 7438   IWN2heYitkg-D4UdqfxcMA                           HEXX kitchen + bar
# 18     xkVMIk_Vqh17f48ZQ_6b0w                   Tom Colicchio's Craftsteak
# 1659   l_GV0hgEoTUf70uJVT0_hg                                         Eat.
# 1630   3BCsAgo_1i4xMuTyLKMLRQ                                   SkinnyFATS
# 1867   EAwh1OmG6t6p3nRaZOW_AA         Ellis Island Hotel, Casino & Brewery
# 100    3GEEy7RP6e4bT4LAiWFMFQ                                   Pizza Rock
# 93     vHz2RLtfUMVRPFmd7VBEHA                 Gordon Ramsay Hell's Kitchen
# 1300   2iTsRqUsPGRH1li1WVRvKQ                               Carson Kitchen
# 176    ugLqbAvBdRDc-gS4hpslXw                                   Yama Sushi
# 3147   xVEtGucSRLk5pxxN0t4i6g                                 Eiffel Tower
# 9475   77h11eWv6HKJAgojLx8G4w                                      Eggslut
# 291    kRgAf6j2y1eR0wOFdzFAuw                                      Firefly
# 3838   _w5hBpkjHs5_Hv3pLeHtIw                         Julian Serrano Tapas
# 7021   QJR4qBUHegWEozSQrGmBPw                                       Olives
# 167    xfWdUmrz2ha3rcigyITV0g                         Gordon Ramsay Burger
# 2461   PXShA3JZMXr2mEH3on5clw                                    Egg Works
# 45     UNI1agsPX2k3eJSJVB91nw                         Hot N Juicy Crawfish
# 182    nUpz0YiBsOK7ff9k3vUJ3A                         Buddy V's Ristorante
# 214    7sb2FYLS2sejZKxRYF9mtg                                       Sakana
# 1447   -ed0Yc9on37RoIoG2ZgxBA                                      Le Thai
# 1972   SVGApDPNdpFlEjwRQThCxA             Juan's Flaming Fajitas & Cantina
# 1533   d_L-rfS1vT3JMzgCUGtiow                                 Border Grill
# 887    N0apJkxIem2E8irTBRKnHw          Wolfgang Puck Bar & Grill Las Vegas
# 51     --9e1ONYQuAa-CB_Rrw7Tw                         Delmonico Steakhouse
# 2192   CiYLq33nAyghFkUR15pP-Q                               Tacos El Gordo
# 4712   bpRo8L8dkhgbJhdIKa9mwA                                STK Las Vegas
# 170    mU3vlAVzTxgmZUu6F4XixA                           Momofuku Las Vegas
# 1288   cJWbbvGmyhFiBpG_5hf5LA                        Hofbräuhaus Las Vegas
# 194    gx2yPrOJSwF1ApJYdGBWIw                              JINYA Ramen Bar
# 3249   IMLrj2klosTFvPRLv56cng                                   Honey Salt
# 3451   A-uZAD4zP3rRxb44WUGV5w                     Soho Japanese Restaurant
# 204    IhNASEZ3XnBHmuuVnWdIwA                                 Brew Tea Bar
# 174    pHJu8tj3sI8eC5aIHLFEfQ                       Nora's Italian Cuisine
# 1322   LFs5jyYdXlzi0SpAYi1eSA                      Maggiano's Little Italy
# 1764   SAIrNOB4PtDA4gziNCucwg                                  Herbs & Rye
# 3007   sqRX-XLlhx4rs2c1TpBf8A                                         Raku
# 1931   eaNenRk_liZBERFFLCXqqQ                             Hobak Korean BBQ
# 5322   eJKnymd0BywNPrJw1IuXVw                         Nacho Daddy Downtown
# 79     j5nPiTwWEFr-VsePew7Sjg                                       Ichiza
# 228    Ec9CBmL3285XkeHaNp-bSQ                                 District One
# 3287   C9ImzBi5fn742ZcAYDww2A           Rise & Shine - A Steak & Egg Place
# 1418   gTlDDzDEHyDQ6iwjNhpI6A                Mount Everest India's Cuisine
# 101    GI-CAiZ_Gg3h21PwrANB4Q                          Mastro's Ocean Club
# 1805   R_ZlcX46pPdjhjmfd043LA                             Top of the World
# 1770   J4CATH00YZrq8Bne2S4_cw                         CUT by Wolfgang Puck
# 2518   EnCIojgP5KTr1leaysFE3A                              Viva Las Arepas
# 26     0d0i0FaJq1GIeW1rS2D-5w                                       Bruxie
# 2787   uW6UHfONAmm8QttPkbMewQ                                Island Flavor
# 1138   IT_4EEIbv6Ox1jBRMyE7pg         Del Frisco's Double Eagle Steakhouse
# 1313   A5Rkh7UymKm0_Rxm9K2PJw                                   Yard House
# 3191   2sx52lDoiEtef7xgPCaoBw                                   VegeNation
# 215    4k3RlMAMd46DZ_JyZU0lMg                                   Ramen Sora
# 4218   q3dJQtwZQrrurNT-1bNKgQ                       Capo's Italian Cuisine
# 144    sNVGdeOPeitJ3OWUQBINzQ                              BabyStacks Cafe
# 82     H8qpFitIesth86zqR4cwYg                     Jean Philippe Patisserie
# 1859   5shgJB7a-2_gdnzc0gsOtg                                      Firefly
# 33     q-zZgXKAQFLEgMp9ZNllgQ                                  Umiya Sushi
# 1305   0NmTwqYEQiKErDv4a55obg                                    Scarpetta
# 2293   zdE82PiD6wquvjYLyhOJNA                                 KoMex Fusion
# 1531   8mIrX_LrOnAqWsB5JrOojQ                         Pinball Hall Of Fame
# 19     Xj7DIGRHEchJ-VVdISazQQ                                     Javier's
# 3641   IZivKqtHyz4-ts8KsnvMrA                                  Kung Fu Tea
# 5875   iIwKW2cBAxjElE8eUzjwqA                        Bobby's Burger Palace
# 2280   vl2IZrNJEA8npSjqXbdwxw                              BabyStacks Cafe
# 207    UYh1N1xQhOh-a7nX92xPzQ                           Brio Tuscan Grille
# 7962   q3oJ6bNRV3OoJrwc95GOwg                                     Dirt Dog
# 2516   UUGoM4q4i8rK2CBRS0xDAw                     Jean Philippe Patisserie
# 4684   0_aeYE2-VbsZts_UpILgDw                    Lazy Dog Restaurant & Bar
# 1740   qqs7LP4TXAoOrSlaKRfz3A                                    DW Bistro
# 251    Sovgwq-E-n6wLqNh3X_rXg                              Lindo Michoacan
#
#        stars_x  review_count_x       city state  p_restaurantid
# 67         4.0            8348  Las Vegas    NV              61
# 70         4.0            8339  Las Vegas    NV              64
# 34         4.0            5763  Las Vegas    NV              34
# 17         4.0            5484  Las Vegas    NV              17
# 23         4.5            5075  Las Vegas    NV              23
# 95         4.0            4286  Las Vegas    NV              86
# 29         4.0            3998  Las Vegas    NV              29
# 97         4.0            3859  Las Vegas    NV              87
# 1050       4.5            3576  Las Vegas    NV             767
# 10626      4.0            3547  Las Vegas    NV            4178
# 2195       4.5            3449  Las Vegas    NV            1524
# 50         4.0            3333  Las Vegas    NV              45
# 1359       4.5            3300  Las Vegas    NV             959
# 1291       4.0            3292  Las Vegas    NV             907
# 1923       4.0            3268  Las Vegas    NV            1370
# 43         4.0            3260  Las Vegas    NV              40
# 124        4.0            3243  Las Vegas    NV             107
# 284        4.0            3159  Las Vegas    NV             225
# 1386       4.5            2862  Las Vegas    NV             972
# 31         4.0            2844  Las Vegas    NV              31
# 177        4.0            2767  Las Vegas    NV             148
# 1787       4.5            2623  Las Vegas    NV            1269
# 25         4.0            2604  Las Vegas    NV              25
# 1809       4.0            2583  Las Vegas    NV            1284
# 3674       4.5            2519  Las Vegas    NV            2221
# 3622       4.5            2442  Las Vegas    NV            2201
# 47         4.5            2423  Las Vegas    NV              43
# 12         4.5            2417  Las Vegas    NV              12
# 8400       4.5            2400  Las Vegas    NV            3632
# 134        4.0            2355  Las Vegas    NV             114
# 7438       4.0            2307  Las Vegas    NV            3417
# 18         4.0            2269  Las Vegas    NV              18
# 1659       4.0            2219  Las Vegas    NV            1171
# 1630       4.5            2206  Las Vegas    NV            1145
# 1867       4.0            2190  Las Vegas    NV            1331
# 100        4.0            2103  Las Vegas    NV              89
# 93         4.5            2041  Las Vegas    NV              84
# 1300       4.5            2024  Las Vegas    NV             913
# 176        4.0            1912  Las Vegas    NV             147
# 3147       4.0            1852  Las Vegas    NV            1995
# 9475       4.0            1826  Las Vegas    NV            3934
# 291        4.5            1809  Las Vegas    NV             227
# 3838       4.0            1785  Las Vegas    NV            2284
# 7021       4.0            1783  Las Vegas    NV            3318
# 167        4.0            1781  Las Vegas    NV             139
# 2461       4.5            1748  Las Vegas    NV            1686
# 45         4.0            1706  Las Vegas    NV              42
# 182        4.0            1662  Las Vegas    NV             151
# 214        4.5            1659  Las Vegas    NV             175
# 1447       4.0            1638  Las Vegas    NV            1008
# 1972       4.5            1624  Las Vegas    NV            1402
# 1533       4.0            1623  Las Vegas    NV            1071
# 887        4.0            1615  Las Vegas    NV             665
# 51         4.0            1613  Las Vegas    NV              46
# 2192       4.0            1579  Las Vegas    NV            1523
# 4712       4.0            1578  Las Vegas    NV            2692
# 170        4.0            1575  Las Vegas    NV             141
# 1288       4.0            1566  Las Vegas    NV             904
# 194        4.0            1522  Las Vegas    NV             161
# 3249       4.0            1517  Las Vegas    NV            2047
# 3451       4.5            1512  Las Vegas    NV            2128
# 204        5.0            1506  Las Vegas    NV             168
# 174        4.0            1506  Las Vegas    NV             145
# 1322       4.0            1476  Las Vegas    NV             931
# 1764       4.0            1461  Las Vegas    NV            1251
# 3007       4.5            1457  Las Vegas    NV            1941
# 1931       4.5            1445  Las Vegas    NV            1376
# 5322       4.0            1445  Las Vegas    NV            2862
# 79         4.0            1444  Las Vegas    NV              72
# 228        4.0            1437  Las Vegas    NV             183
# 3287       4.0            1429  Las Vegas    NV            2064
# 1418       4.5            1421  Las Vegas    NV             988
# 101        4.5            1406  Las Vegas    NV              90
# 1805       4.0            1401  Las Vegas    NV            1281
# 1770       4.0            1397  Las Vegas    NV            1256
# 2518       4.5            1395  Las Vegas    NV            1713
# 26         4.5            1394  Las Vegas    NV              26
# 2787       4.5            1380  Las Vegas    NV            1818
# 1138       4.5            1379  Las Vegas    NV             813
# 1313       4.0            1375  Las Vegas    NV             923
# 3191       4.5            1367  Las Vegas    NV            2022
# 215        4.0            1356  Las Vegas    NV             176
# 4218       4.0            1349  Las Vegas    NV            2457
# 144        4.0            1334  Las Vegas    NV             119
# 82         4.0            1319  Las Vegas    NV              75
# 1859       4.5            1315  Las Vegas    NV            1324
# 33         4.0            1311  Las Vegas    NV              33
# 1305       4.0            1291  Las Vegas    NV             917
# 2293       4.5            1258  Las Vegas    NV            1570
# 1531       4.5            1258  Las Vegas    NV            1069
# 19         4.0            1255  Las Vegas    NV              19
# 3641       4.5            1253  Las Vegas    NV            2207
# 5875       4.0            1249  Las Vegas    NV            3029
# 2280       4.0            1247  Las Vegas    NV            1562
# 207        4.0            1231  Las Vegas    NV             171
# 7962       4.5            1230  Las Vegas    NV            3565
# 2516       4.0            1227  Las Vegas    NV            1712
# 4684       4.0            1207  Las Vegas    NV            2678
# 1740       4.5            1203  Las Vegas    NV            1232
# 251        4.0            1203  Las Vegas    NV             198

# %%
p_df = ref_df[ref_df['city']=='Phoenix']
p_df = p_df[p_df['state']=='AZ']
p_df = p_df[p_df['stars_x']>=4.0]
p_df = p_df.sort_values(by=['review_count_x'], ascending=False)
p_df.head(25)
# Out:
#                  business_id                          name_x  stars_x  \
# 432   VyVIneSU7XAWgMBllI6LnQ                         Bobby Q      4.5
# 1022  pSQFynH1VxkfSmehRXlZWw                 Pizzeria Bianco      4.0
# 481   OgJ0KxwJcJ9R5bUK0ixCbg                     Lux Central      4.5
# 879   yNPh5SO-7wr8HPpVCDPbXQ            The Arrogant Butcher      4.0
# 665   frCxZS7lPhEnQRJ3UY6m7A                    La Santisima      4.0
# 590   9a3DrZvpYxVs3k_qwlCNSw                            Cibo      4.5
# 6895  Xg5qEQiB-7L6kGJ5F4K3bQ                 Little Miss BBQ      5.0
# 1056  YPavuOh2XsnRbLfl0DH2lQ       Lo-Lo's Chicken & Waffles      4.0
# 518   L2p0vO3fsS2LC6hhQo3CzA            Matt's Big Breakfast      4.0
# 885   cHdJXLlKNWixBXpDwEGb_A                   Chino Bandido      4.0
# 475   z6-reuC5BYf_Rth9gMBfgQ          St. Francis Restaurant      4.0
# 541   whAwdYVty-jSNRhrYT2zHA      Pappadeaux Seafood Kitchen      4.0
# 660   3C5Z9homtzkWHouH2BHXYQ                      Taco Guild      4.0
# 652   eS29S_06lvsDW04wVrIVxg                     Barrio Café      4.0
# 622   E4JyAzB5_2quptwtemyhYA        Original Breakfast House      4.5
# 663   IsoLzudHC50oJLiEWpwV-w               Chelsea's Kitchen      4.0
# 670   utIA0LyQmwP-9DRyxUe6qQ          Snooze, An A.M. Eatery      4.0
# 323   u-SJ5QUwrNquL9VnXwl8cg                 Postino Arcadia      4.5
# 9331  7m1Oa1VYV98UUuo_6i0EZg  Paradise Valley Burger Company      4.5
# 758   k1QpHAkzKTrFYfk6u--VgQ                      The Parlor      4.5
# 659   LelAlfuj5oVRF9CQdWLsNQ                       The Henry      4.0
# 341   mnwRtuVQEsIUomBchu0gwg           OHSO Brewery- Arcadia      4.0
# 829   XMMLRvV4IMxIGyc4H37LxA               True Food Kitchen      4.0
# 9349  S-oLPRdhlyL5HAknBKTUcQ                    Harumi Sushi      4.5
# 478   J07TDs6qnTIaxm48EL1cKQ              Hula's Modern Tiki      4.0
#
#       review_count_x     city state  p_restaurantid
# 432             2556  Phoenix    AZ             347
# 1022            2276  Phoenix    AZ             752
# 481             2046  Phoenix    AZ             390
# 879             1972  Phoenix    AZ             659
# 665             1967  Phoenix    AZ             525
# 590             1955  Phoenix    AZ             473
# 6895            1936  Phoenix    AZ            3284
# 1056            1807  Phoenix    AZ             771
# 518             1793  Phoenix    AZ             417
# 885             1600  Phoenix    AZ             663
# 475             1508  Phoenix    AZ             384
# 541             1501  Phoenix    AZ             436
# 660             1468  Phoenix    AZ             523
# 652             1413  Phoenix    AZ             516
# 622             1403  Phoenix    AZ             496
# 663             1363  Phoenix    AZ             524
# 670             1287  Phoenix    AZ             529
# 323             1254  Phoenix    AZ             252
# 9331            1217  Phoenix    AZ            3832
# 758             1199  Phoenix    AZ             584
# 659             1176  Phoenix    AZ             522
# 341             1163  Phoenix    AZ             268
# 829             1137  Phoenix    AZ             623
# 9349            1107  Phoenix    AZ            3842
# 478             1103  Phoenix    AZ             387
